# %% [markdown]
# # Train a hornet classifier
# We train a deep neurel network to classify our extracted images of hornets.

# %%
# %%bash
# pip install torch==1.10.2
# pip install torchvision==0.11.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.10.2
#   Downloading torch-1.10.2-cp37-cp37m-manylinux1_x86_64.whl (881.9 MB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.2) (4.1.1)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.0+cu113
#     Uninstalling torch-1.12.0+cu113:
#       Successfully uninstalled torch-1.12.0+cu113
# Successfully installed torch-1.10.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchvision==0.11.3
#   Downloading torchvision-0.11.3-cp37-cp37m-manylinux1_x86_64.whl (23.2 MB)
# Requirement already satisfied: torch==1.10.2 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.3) (1.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.3) (1.21.6)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.3) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.2->torchvision==0.11.3) (4.1.1)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.0+cu113
#     Uninstalling torchvision-0.13.0+cu113:
#       Successfully uninstalled torchvision-0.13.0+cu113
# Successfully installed torchvision-0.11.3
# tcmalloc: large alloc 1147494400 bytes == 0x39896000 @  0x7f6d00687615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.0+cu113 requires torch==1.12.0, but you have torch 1.10.2 which is incompatible.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.10.2 which is incompatible.
# torchaudio 0.12.0+cu113 requires torch==1.12.0, but you have torch 1.10.2 which is incompatible.

# %%
import os
import sys
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

# Magic: automatically reload imports + inline plots
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# Experiment name
exp_name = 'resnet-new-lr001-2'

# Root directory
drive.mount('/content/gdrive', force_remount=True)  # Mount Google Drive
root_dir = '/content/gdrive/MyDrive/Projects/vespai'
sys.path.insert(0, root_dir)
os.chdir(root_dir)
data_dir = os.path.join(root_dir, 'datasets/extracts-21')
weights_dir = os.path.join(
    root_dir, 'models/classifier-runs/' + exp_name + '/weights',
)
os.makedirs(weights_dir, exist_ok=True)

# Save figures
save_ok = True
fig_dir = os.path.join(root_dir, 'models/classifier-runs/' + exp_name + '/figs')
os.makedirs(fig_dir, exist_ok=True)

# Set device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Device: ', device)

# GPU info
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
   print(gpu_info)

# RAM availability
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Mounted at /content/gdrive
# Device:  cuda:0
# Fri Jul 29 14:05:52 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ## Load and prepare the data

# %%
import glob

# Locate data
train_files = glob.glob(os.path.join(data_dir, 'train/*.jpeg'))
val_files = glob.glob(os.path.join(data_dir, 'val/*.jpeg'))
test_files = glob.glob(os.path.join(data_dir, 'test/*.jpeg'))

# %%
# Class names
class_dict = {
     0: 'Vespa crabro',
     1: 'Vespa velutina',
     2: 'Other',
}

# Plot example
rand_file = train_files[np.random.randint(len(train_files), size=1)[0]]
rand_image = cv2.imread(os.path.join(rand_file))  # image.shape = (h, w, c)
rand_image = cv2.cvtColor(rand_image, cv2.COLOR_BGR2RGB)
print('Class: ', int(rand_file[-6]))
print('Class name: ', class_dict[int(rand_file[-6])])

plt.imshow(rand_image)
plt.show()
# Out:
# Class:  1
# Class name:  Vespa velutina

# %% [markdown]
# ### Torch datasets
# Unaugmented example using `HornetDataset` class. From this example below we note that the images need preprocessing to have the same shape and normalisation.

# %%
from models.classifier.loader import HornetDataset

example_set = HornetDataset(train_files)

fig = plt.figure()
for i in range(len(example_set)):
    image, target = example_set[i]
    print('Image shape: ', image.shape) 
    print('Image class: {}'.format(class_dict[int(target[1])]))
    print('\n')
    
    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    plt.imshow(image)

    if i == 3:
        plt.show()
        break
# Out:
# Image shape:  (169, 119, 3)
# Image class: Vespa velutina
#
#
# Image shape:  (168, 162, 3)
# Image class: Vespa velutina
#
#
# Image shape:  (153, 134, 3)
# Image class: Vespa velutina
#
#
# Image shape:  (94, 167, 3)
# Image class: Vespa velutina

# %% [markdown]
# Demonstrate the use of transformations to augment images.

# %%
from models.classifier.loader import Rescale, RandomCrop
from torchvision import transforms

scale = Rescale(256)
crop = RandomCrop(128)
both = transforms.Compose([Rescale(256), RandomCrop(224)])

# Apply each of the above transforms on sample.
sample = example_set[65]
fig = plt.figure()
for i, aug in enumerate([scale, crop, both]):
    aug_sample = aug(sample)
    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(aug).__name__)
    plt.imshow(aug_sample[0])

plt.show()

# %% [markdown]
# ### Construct dataloaders

# %%
from models.classifier.loader import get_hornet_loader
from models.classifier.utils import show_batch

# Get data loaders
train_loader = get_hornet_loader(train_files, batch_size=64, augment=True)
val_loader = get_hornet_loader(val_files, batch_size=1, augment=False)

# Print samples of batches
for idx, sample_batch in enumerate(train_loader):
    print('Batch number ', idx, ', batch size: ', sample_batch[0].size())

    # Observe 4th batch and stop.
    if idx == 3:
        plt.figure(figsize=(12, 12))
        show_batch(sample_batch)
        plt.axis('off')
        plt.ioff()
        plt.savefig(os.path.join(fig_dir, 'augs.png'))
        plt.show()
        break
# Out:
# Batch number  0 , batch size:  torch.Size([64, 3, 256, 256])
# Batch number  1 , batch size:  torch.Size([64, 3, 256, 256])
# Batch number  2 , batch size:  torch.Size([64, 3, 256, 256])
# Batch number  3 , batch size:  torch.Size([64, 3, 256, 256])

# %% [markdown]
# ## Training a classifier network
# We first define a model to classify into either Vespa crabro or Vespa velutina. We don't use `nn.Softmax()` as we seperate binary classifications into the above two classes (one-against-rest) in order to account for examples outside those classes. Probabilities are obtained with the logistic sigmoids `nn.Sigmoid()`. To complement this choice we apply Binary Cross-Entropy loss to the outputs.

# %%
import torch.nn as nn
import torch.nn.functional as F


class BasicNet(nn.Module):
    """Basic convolutional classifier network."""
    
    def __init__(self, num_classes=2):
        super(BasicNet, self).__init__()
        self.norm8 = nn.BatchNorm2d(8)
        self.norm16 = nn.BatchNorm2d(16)
        self.norm32 = nn.BatchNorm2d(32)
        self.conv1 = nn.Conv2d(3, 8, 5, 2, 2)
        self.conv2 = nn.Conv2d(8, 16, 5, 2, 2)
        self.conv3 = nn.Conv2d(16, 32, 5, 2, 2)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(32 * 8 * 8, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, num_classes)
        self.final_activation = nn.Sigmoid()

    def forward(self, x):
        """Forward function expects x.shape = (N, 3, 256, 256)."""
        x = self.conv1(x)  # x.shape = (N, 8, 128, 128)
        x = F.relu(self.norm8(x))
        x = self.conv2(x)  # x.shape = (N, 16, 64, 64)
        x = F.relu(self.norm16(x))
        x = self.pool(x)  # x.shape = (N, 16, 32, 32)
        x = self.conv3(x)  # x.shape = (N, 32, 16, 16)
        x = F.relu(self.norm32(x))
        x = self.pool(x)  # x.shape = (N, 32, 8, 8)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return self.final_activation(x)

# %%
import torch.nn as nn
from torchvision.models import resnet18

class ResNetClassifier(nn.Module):
    """Classifier based on ResNet.
    
    Adapt final ResNet layer `self.resnet.fc` to map to two classes. Activate
    with logisitic sigmoid for uncorrelated binary classification.
    """
    
    def __init__(self, num_classes, use_pretraining=True):
        super(ResNetClassifier, self).__init__()

        # Instantiate model
        self.resnet = resnet18(pretrained=use_pretraining)

        # Bespoke alterations
        self.resnet.fc = nn.Linear(512, num_classes, bias=False)  # New heads
        self.final_activation = nn.Sigmoid() # or nn.Softmax(dim=-1)

    def forward(self, x):
        x = self.resnet(x)
        x = self.final_activation(x)
        return x

# %%
# %%script false
#
# # Print model's state_dict
# print("* Model's state_dict:")
# for param_tensor in model.state_dict():
#     print(param_tensor, "\t", model.state_dict()[param_tensor].size())
#
# print('\n')
#
# # Print optimizer's state_dict
# print("* Optimiser's state_dict:")
# for var_name in optimiser.state_dict():
#     print(var_name, "\t", optimiser.state_dict()[var_name])
#
# # print(model)

# %%
# Instantiate model
model = ResNetClassifier(num_classes=2, use_pretraining=False)
model.eval()

# Save location
last_weights = os.path.join(weights_dir, 'last.pt')
best_weights = os.path.join(weights_dir, 'best.pt')

# Train from previous best weights
resume_weights = False
if os.path.exists(best_weights) and resume_weights:
    model.load_state_dict(torch.load(best_weights))

# %% [markdown]
# ### Training routine

# %%
import time
from tqdm.notebook import tqdm
import torch.optim as optim
from models.classifier.utils import accuracy

num_epochs = 200
epoch_progress_cut_off = 25
learning_rate = 0.001
test_threshold = 0.8
best_epoch = 0

thresholds = torch.linspace(0.5, 0.95, 10)
assert any(thresholds == test_threshold)

# Loss function
criterion = torch.nn.BCELoss()

# Optimiser
# optimiser = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
optimiser = optim.Adam(model.parameters(), lr=learning_rate)

# Record statistics
sub_stats = 5
batch_freq = int(len(train_loader) / sub_stats)  # To print sub-epoch stats
epoch_freq = 1  # Number of epochs on which to validate model
train_loss, val_loss, train_acc, val_acc = [], [], [], []

# Training mode
model.train()

# Iterate training proceedure
for epoch in tqdm(range(num_epochs)):

    print('\nEpoch {:02d}\n--------'.format(epoch))
    start_time = time.time()
    t0 = start_time

    # Accumulated loss in given epoch
    running_loss = 0.0
    for batch, data in enumerate(train_loader, start=0):
        
        # Perform optimisation step
        images, labels = data  # Retrieve batch data
        optimiser.zero_grad()  # Zero parameter gradients
        outputs = model(images)  # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()  # Backpropagate
        optimiser.step()  # Update gradients
        running_loss += loss.item()  # Record loss

        if batch % batch_freq == 0:

            # Training loss
            if not batch == 0:
                running_loss /= batch_freq
            train_loss.append(running_loss)
            print('Batch {:02d} | Training loss {:00.4f} | Running time {:.2f}s'
                  .format(batch, running_loss, time.time() - t0)
                  )
            t0 = time.time()
            running_loss = 0.0
    
    if epoch % epoch_freq == 0:

        # Evaluation mode
        model.eval()
        
        # Validation loss
        running_loss = 0.0
        for image, target in val_loader:
            with torch.no_grad():
                prob = model(image)
                running_loss += criterion(prob, target).item()
        val_loss.append(running_loss / len(val_loader))

        # Validation and trianing accuracy
        th_ind = (thresholds == test_threshold)
        val_acc.append(float(accuracy(model, val_loader)[th_ind]))
        # train_acc.append(float(accuracy(model, train_loader)[th_ind]))

        print('\nSummary:\n'
              '\tValidation acc: {:.2%} (at an {:.0%} threshold) \n'
              '\tValidation loss: {:.4f}\n'
              '\tEpoch running time: {:.2f}s'
              .format(val_acc[-1], test_threshold,
                      val_loss[-1],
                      time.time() - start_time,
                      )
        )
        
        # Save last weights
        print(f'Saving `last` model weights at epoch {epoch}')
        torch.save(model.state_dict(), last_weights)

        # Save best weights wrt accuracy
        if epoch == 0 or all(loss > val_loss[-1] for loss in val_loss[:-1]):
            print(f'* Saving `best` model weights at epoch {epoch} *\n')
            torch.save(model.state_dict(), best_weights)
            best_epoch = epoch
        else:
            print(f'Previous `best` weights recorded at epoch {best_epoch}\n')

        if epoch - best_epoch >= epoch_progress_cut_off:
            print(f'Final epoch before terminating training: {epoch}')
            num_epochs = epoch + 1
            break

print(f'Finished Training. Best validation loss at epoch: {best_epoch}')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch 00
# --------
# Batch 00 | Training loss 0.7408 | Running time 5.77s
# Batch 05 | Training loss 0.9937 | Running time 27.30s
# Batch 10 | Training loss 0.6340 | Running time 27.11s
# Batch 15 | Training loss 0.4822 | Running time 26.13s
# Batch 20 | Training loss 0.4496 | Running time 26.52s
# Batch 25 | Training loss 0.3882 | Running time 26.12s
#
# Summary:
# 	Validation acc: 49.14% (at an 80% threshold)
# 	Validation loss: 1.2134
# 	Epoch running time: 178.77s
# Saving `last` model weights at epoch 0
# * Saving `best` model weights at epoch 0 *
#
#
# Epoch 01
# --------
# Batch 00 | Training loss 1.7759 | Running time 4.93s
# Batch 05 | Training loss 0.7063 | Running time 25.44s
# Batch 10 | Training loss 0.6369 | Running time 24.76s
# Batch 15 | Training loss 0.6060 | Running time 25.01s
# Batch 20 | Training loss 0.5584 | Running time 25.20s
# Batch 25 | Training loss 0.5680 | Running time 24.82s
#
# Summary:
# 	Validation acc: 34.05% (at an 80% threshold)
# 	Validation loss: 0.4878
# 	Epoch running time: 169.63s
# Saving `last` model weights at epoch 1
# * Saving `best` model weights at epoch 1 *
#
#
# Epoch 02
# --------
# Batch 00 | Training loss 0.4915 | Running time 4.91s
# Batch 05 | Training loss 0.5197 | Running time 24.67s
# Batch 10 | Training loss 0.4634 | Running time 25.24s
# Batch 15 | Training loss 0.4374 | Running time 25.94s
# Batch 20 | Training loss 0.4802 | Running time 24.85s
# Batch 25 | Training loss 0.5276 | Running time 25.80s
#
# Summary:
# 	Validation acc: 20.26% (at an 80% threshold)
# 	Validation loss: 0.3542
# 	Epoch running time: 168.85s
# Saving `last` model weights at epoch 2
# * Saving `best` model weights at epoch 2 *
#
#
# Epoch 03
# --------
# Batch 00 | Training loss 0.4956 | Running time 4.96s
# Batch 05 | Training loss 0.4817 | Running time 24.79s
# Batch 10 | Training loss 0.4909 | Running time 26.11s
# Batch 15 | Training loss 0.4459 | Running time 25.77s
# Batch 20 | Training loss 0.3271 | Running time 25.69s
# Batch 25 | Training loss 0.3373 | Running time 24.86s
#
# Summary:
# 	Validation acc: 73.28% (at an 80% threshold)
# 	Validation loss: 0.2904
# 	Epoch running time: 170.53s
# Saving `last` model weights at epoch 3
# * Saving `best` model weights at epoch 3 *
#
#
# Epoch 04
# --------
# Batch 00 | Training loss 0.3977 | Running time 5.12s
# Batch 05 | Training loss 0.4656 | Running time 24.83s
# Batch 10 | Training loss 0.4623 | Running time 25.05s
# Batch 15 | Training loss 0.3944 | Running time 25.40s
# Batch 20 | Training loss 0.4216 | Running time 25.03s
# Batch 25 | Training loss 0.4065 | Running time 25.05s
#
# Summary:
# 	Validation acc: 49.14% (at an 80% threshold)
# 	Validation loss: 0.3356
# 	Epoch running time: 170.13s
# Saving `last` model weights at epoch 4
# Previous `best` weights recorded at epoch 3
#
#
# Epoch 05
# --------
# Batch 00 | Training loss 0.4154 | Running time 4.88s
# Batch 05 | Training loss 0.4361 | Running time 24.51s
# Batch 10 | Training loss 0.4116 | Running time 24.95s
# Batch 15 | Training loss 0.4070 | Running time 26.09s
# Batch 20 | Training loss 0.4475 | Running time 24.71s
# Batch 25 | Training loss 0.4185 | Running time 24.68s
#
# Summary:
# 	Validation acc: 57.33% (at an 80% threshold)
# 	Validation loss: 0.2721
# 	Epoch running time: 169.56s
# Saving `last` model weights at epoch 5
# * Saving `best` model weights at epoch 5 *
#
#
# Epoch 06
# --------
# Batch 00 | Training loss 0.3309 | Running time 5.20s
# Batch 05 | Training loss 0.3783 | Running time 26.56s
# Batch 10 | Training loss 0.3788 | Running time 25.04s
# Batch 15 | Training loss 0.4176 | Running time 25.55s
# Batch 20 | Training loss 0.4110 | Running time 25.39s
# Batch 25 | Training loss 0.4276 | Running time 24.89s
#
# Summary:
# 	Validation acc: 71.98% (at an 80% threshold)
# 	Validation loss: 0.2565
# 	Epoch running time: 170.35s
# Saving `last` model weights at epoch 6
# * Saving `best` model weights at epoch 6 *
#
#
# Epoch 07
# --------
# Batch 00 | Training loss 0.4191 | Running time 4.95s
# Batch 05 | Training loss 0.3832 | Running time 26.36s
# Batch 10 | Training loss 0.3847 | Running time 25.64s
# Batch 15 | Training loss 0.3693 | Running time 25.83s
# Batch 20 | Training loss 0.3160 | Running time 25.96s
# Batch 25 | Training loss 0.3211 | Running time 26.04s
#
# Summary:
# 	Validation acc: 82.33% (at an 80% threshold)
# 	Validation loss: 0.2106
# 	Epoch running time: 174.76s
# Saving `last` model weights at epoch 7
# * Saving `best` model weights at epoch 7 *
#
#
# Epoch 08
# --------
# Batch 00 | Training loss 0.4907 | Running time 4.93s
# Batch 05 | Training loss 0.3446 | Running time 25.75s
# Batch 10 | Training loss 0.4583 | Running time 25.15s
# Batch 15 | Training loss 0.4238 | Running time 25.03s
# Batch 20 | Training loss 0.3570 | Running time 25.35s
# Batch 25 | Training loss 0.4194 | Running time 25.03s
#
# Summary:
# 	Validation acc: 65.09% (at an 80% threshold)
# 	Validation loss: 0.2596
# 	Epoch running time: 171.12s
# Saving `last` model weights at epoch 8
# Previous `best` weights recorded at epoch 7
#
#
# Epoch 09
# --------
# Batch 00 | Training loss 0.3908 | Running time 5.02s
# Batch 05 | Training loss 0.3869 | Running time 25.77s
# Batch 10 | Training loss 0.3642 | Running time 24.89s
# Batch 15 | Training loss 0.3645 | Running time 24.74s
# Batch 20 | Training loss 0.3655 | Running time 25.41s
# Batch 25 | Training loss 0.3551 | Running time 25.44s
#
# Summary:
# 	Validation acc: 79.74% (at an 80% threshold)
# 	Validation loss: 0.2026
# 	Epoch running time: 171.15s
# Saving `last` model weights at epoch 9
# * Saving `best` model weights at epoch 9 *
#
#
# Epoch 10
# --------
# Batch 00 | Training loss 0.3992 | Running time 5.09s
# Batch 05 | Training loss 0.3101 | Running time 25.28s
# Batch 10 | Training loss 0.3239 | Running time 25.12s
# Batch 15 | Training loss 0.3339 | Running time 26.12s
# Batch 20 | Training loss 0.3697 | Running time 25.70s
# Batch 25 | Training loss 0.3367 | Running time 25.66s
#
# Summary:
# 	Validation acc: 87.07% (at an 80% threshold)
# 	Validation loss: 0.1324
# 	Epoch running time: 169.88s
# Saving `last` model weights at epoch 10
# * Saving `best` model weights at epoch 10 *
#
#
# Epoch 11
# --------
# Batch 00 | Training loss 0.4113 | Running time 4.95s
# Batch 05 | Training loss 0.3022 | Running time 25.52s
# Batch 10 | Training loss 0.3458 | Running time 25.86s
# Batch 15 | Training loss 0.2837 | Running time 25.41s
# Batch 20 | Training loss 0.2865 | Running time 25.30s
# Batch 25 | Training loss 0.4438 | Running time 25.51s
#
# Summary:
# 	Validation acc: 76.72% (at an 80% threshold)
# 	Validation loss: 0.2124
# 	Epoch running time: 171.79s
# Saving `last` model weights at epoch 11
# Previous `best` weights recorded at epoch 10
#
#
# Epoch 12
# --------
# Batch 00 | Training loss 0.2568 | Running time 5.01s
# Batch 05 | Training loss 0.3399 | Running time 25.38s
# Batch 10 | Training loss 0.3450 | Running time 26.01s
# Batch 15 | Training loss 0.2340 | Running time 26.24s
# Batch 20 | Training loss 0.3188 | Running time 25.66s
# Batch 25 | Training loss 0.3088 | Running time 25.25s
#
# Summary:
# 	Validation acc: 85.34% (at an 80% threshold)
# 	Validation loss: 0.1750
# 	Epoch running time: 172.47s
# Saving `last` model weights at epoch 12
# Previous `best` weights recorded at epoch 10
#
#
# Epoch 13
# --------
# Batch 00 | Training loss 0.2035 | Running time 4.96s
# Batch 05 | Training loss 0.2510 | Running time 26.02s
# Batch 10 | Training loss 0.2646 | Running time 25.22s
# Batch 15 | Training loss 0.3216 | Running time 24.60s
# Batch 20 | Training loss 0.2339 | Running time 24.94s
# Batch 25 | Training loss 0.2475 | Running time 25.53s
#
# Summary:
# 	Validation acc: 92.24% (at an 80% threshold)
# 	Validation loss: 0.0995
# 	Epoch running time: 171.00s
# Saving `last` model weights at epoch 13
# * Saving `best` model weights at epoch 13 *
#
#
# Epoch 14
# --------
# Batch 00 | Training loss 0.2242 | Running time 4.93s
# Batch 05 | Training loss 0.2852 | Running time 26.07s
# Batch 10 | Training loss 0.2609 | Running time 25.22s
# Batch 15 | Training loss 0.2107 | Running time 25.22s
# Batch 20 | Training loss 0.1992 | Running time 25.31s
# Batch 25 | Training loss 0.1813 | Running time 25.53s
#
# Summary:
# 	Validation acc: 93.97% (at an 80% threshold)
# 	Validation loss: 0.0820
# 	Epoch running time: 171.90s
# Saving `last` model weights at epoch 14
# * Saving `best` model weights at epoch 14 *
#
#
# Epoch 15
# --------
# Batch 00 | Training loss 0.1097 | Running time 4.91s
# Batch 05 | Training loss 0.2051 | Running time 25.31s
# Batch 10 | Training loss 0.2165 | Running time 25.43s
# Batch 15 | Training loss 0.3256 | Running time 24.81s
# Batch 20 | Training loss 0.4001 | Running time 25.36s
# Batch 25 | Training loss 0.2285 | Running time 25.17s
#
# Summary:
# 	Validation acc: 90.09% (at an 80% threshold)
# 	Validation loss: 0.0986
# 	Epoch running time: 170.71s
# Saving `last` model weights at epoch 15
# Previous `best` weights recorded at epoch 14
#
#
# Epoch 16
# --------
# Batch 00 | Training loss 0.1920 | Running time 5.00s
# Batch 05 | Training loss 0.2757 | Running time 24.78s
# Batch 10 | Training loss 0.2269 | Running time 24.88s
# Batch 15 | Training loss 0.1599 | Running time 26.01s
# Batch 20 | Training loss 0.1199 | Running time 25.76s
# Batch 25 | Training loss 0.1656 | Running time 25.04s
#
# Summary:
# 	Validation acc: 95.69% (at an 80% threshold)
# 	Validation loss: 0.0654
# 	Epoch running time: 167.80s
# Saving `last` model weights at epoch 16
# * Saving `best` model weights at epoch 16 *
#
#
# Epoch 17
# --------
# Batch 00 | Training loss 0.0822 | Running time 4.90s
# Batch 05 | Training loss 0.1160 | Running time 24.86s
# Batch 10 | Training loss 0.1943 | Running time 24.60s
# Batch 15 | Training loss 0.2024 | Running time 24.62s
# Batch 20 | Training loss 0.1622 | Running time 24.62s
# Batch 25 | Training loss 0.1448 | Running time 26.11s
#
# Summary:
# 	Validation acc: 87.07% (at an 80% threshold)
# 	Validation loss: 0.1069
# 	Epoch running time: 166.93s
# Saving `last` model weights at epoch 17
# Previous `best` weights recorded at epoch 16
#
#
# Epoch 18
# --------
# Batch 00 | Training loss 0.1702 | Running time 4.93s
# Batch 05 | Training loss 0.1580 | Running time 26.11s
# Batch 10 | Training loss 0.1032 | Running time 25.85s
# Batch 15 | Training loss 0.1203 | Running time 24.85s
# Batch 20 | Training loss 0.1213 | Running time 25.87s
# Batch 25 | Training loss 0.0844 | Running time 25.46s
#
# Summary:
# 	Validation acc: 94.83% (at an 80% threshold)
# 	Validation loss: 0.0486
# 	Epoch running time: 172.52s
# Saving `last` model weights at epoch 18
# * Saving `best` model weights at epoch 18 *
#
#
# Epoch 19
# --------
# Batch 00 | Training loss 0.0876 | Running time 5.03s
# Batch 05 | Training loss 0.2167 | Running time 25.91s
# Batch 10 | Training loss 0.1331 | Running time 25.82s
# Batch 15 | Training loss 0.1147 | Running time 26.10s
# Batch 20 | Training loss 0.0893 | Running time 25.41s
# Batch 25 | Training loss 0.1679 | Running time 25.82s
#
# Summary:
# 	Validation acc: 92.24% (at an 80% threshold)
# 	Validation loss: 0.0522
# 	Epoch running time: 174.17s
# Saving `last` model weights at epoch 19
# Previous `best` weights recorded at epoch 18
#
#
# Epoch 20
# --------
# Batch 00 | Training loss 0.0891 | Running time 4.99s
# Batch 05 | Training loss 0.1302 | Running time 24.47s
# Batch 10 | Training loss 0.1158 | Running time 24.89s
# Batch 15 | Training loss 0.1146 | Running time 24.86s
# Batch 20 | Training loss 0.0784 | Running time 24.65s
# Batch 25 | Training loss 0.1113 | Running time 25.61s
#
# Summary:
# 	Validation acc: 95.26% (at an 80% threshold)
# 	Validation loss: 0.0371
# 	Epoch running time: 168.71s
# Saving `last` model weights at epoch 20
# * Saving `best` model weights at epoch 20 *
#
#
# Epoch 21
# --------
# Batch 00 | Training loss 0.0382 | Running time 4.98s
# Batch 05 | Training loss 0.0566 | Running time 24.95s
# Batch 10 | Training loss 0.0658 | Running time 25.29s
# Batch 15 | Training loss 0.0825 | Running time 25.28s
# Batch 20 | Training loss 0.1734 | Running time 24.81s
# Batch 25 | Training loss 0.0647 | Running time 25.15s
#
# Summary:
# 	Validation acc: 92.24% (at an 80% threshold)
# 	Validation loss: 0.1155
# 	Epoch running time: 169.71s
# Saving `last` model weights at epoch 21
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 22
# --------
# Batch 00 | Training loss 0.1627 | Running time 4.98s
# Batch 05 | Training loss 0.1234 | Running time 25.04s
# Batch 10 | Training loss 0.1626 | Running time 25.48s
# Batch 15 | Training loss 0.1493 | Running time 24.58s
# Batch 20 | Training loss 0.0883 | Running time 24.46s
# Batch 25 | Training loss 0.0561 | Running time 25.06s
#
# Summary:
# 	Validation acc: 96.55% (at an 80% threshold)
# 	Validation loss: 0.0460
# 	Epoch running time: 168.74s
# Saving `last` model weights at epoch 22
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 23
# --------
# Batch 00 | Training loss 0.0863 | Running time 5.01s
# Batch 05 | Training loss 0.1627 | Running time 24.69s
# Batch 10 | Training loss 0.1067 | Running time 25.71s
# Batch 15 | Training loss 0.0885 | Running time 24.46s
# Batch 20 | Training loss 0.0781 | Running time 24.49s
# Batch 25 | Training loss 0.0416 | Running time 24.37s
#
# Summary:
# 	Validation acc: 92.67% (at an 80% threshold)
# 	Validation loss: 0.1193
# 	Epoch running time: 169.34s
# Saving `last` model weights at epoch 23
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 24
# --------
# Batch 00 | Training loss 0.0992 | Running time 5.03s
# Batch 05 | Training loss 0.1241 | Running time 25.97s
# Batch 10 | Training loss 0.1021 | Running time 25.86s
# Batch 15 | Training loss 0.1131 | Running time 25.13s
# Batch 20 | Training loss 0.1404 | Running time 25.46s
# Batch 25 | Training loss 0.0812 | Running time 25.35s
#
# Summary:
# 	Validation acc: 95.69% (at an 80% threshold)
# 	Validation loss: 0.0489
# 	Epoch running time: 172.31s
# Saving `last` model weights at epoch 24
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 25
# --------
# Batch 00 | Training loss 0.0708 | Running time 5.11s
# Batch 05 | Training loss 0.0560 | Running time 24.90s
# Batch 10 | Training loss 0.1140 | Running time 25.18s
# Batch 15 | Training loss 0.0644 | Running time 25.63s
# Batch 20 | Training loss 0.0578 | Running time 25.91s
# Batch 25 | Training loss 0.0533 | Running time 25.76s
#
# Summary:
# 	Validation acc: 96.55% (at an 80% threshold)
# 	Validation loss: 0.0500
# 	Epoch running time: 171.24s
# Saving `last` model weights at epoch 25
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 26
# --------
# Batch 00 | Training loss 0.0372 | Running time 4.95s
# Batch 05 | Training loss 0.0493 | Running time 25.06s
# Batch 10 | Training loss 0.0543 | Running time 24.57s
# Batch 15 | Training loss 0.0966 | Running time 25.56s
# Batch 20 | Training loss 0.1161 | Running time 24.54s
# Batch 25 | Training loss 0.1839 | Running time 24.46s
#
# Summary:
# 	Validation acc: 93.53% (at an 80% threshold)
# 	Validation loss: 0.0578
# 	Epoch running time: 167.26s
# Saving `last` model weights at epoch 26
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 27
# --------
# Batch 00 | Training loss 0.2113 | Running time 4.90s
# Batch 05 | Training loss 0.1425 | Running time 25.17s
# Batch 10 | Training loss 0.0917 | Running time 26.04s
# Batch 15 | Training loss 0.0996 | Running time 24.92s
# Batch 20 | Training loss 0.1205 | Running time 25.50s
# Batch 25 | Training loss 0.0507 | Running time 25.36s
#
# Summary:
# 	Validation acc: 95.69% (at an 80% threshold)
# 	Validation loss: 0.0499
# 	Epoch running time: 168.12s
# Saving `last` model weights at epoch 27
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 28
# --------
# Batch 00 | Training loss 0.1825 | Running time 4.94s
# Batch 05 | Training loss 0.0592 | Running time 25.27s
# Batch 10 | Training loss 0.0902 | Running time 24.58s
# Batch 15 | Training loss 0.0404 | Running time 25.27s
# Batch 20 | Training loss 0.0356 | Running time 26.01s
# Batch 25 | Training loss 0.0452 | Running time 25.42s
#
# Summary:
# 	Validation acc: 89.66% (at an 80% threshold)
# 	Validation loss: 0.1600
# 	Epoch running time: 173.13s
# Saving `last` model weights at epoch 28
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 29
# --------
# Batch 00 | Training loss 0.2826 | Running time 4.88s
# Batch 05 | Training loss 0.0481 | Running time 24.47s
# Batch 10 | Training loss 0.0495 | Running time 25.18s
# Batch 15 | Training loss 0.1275 | Running time 24.95s
# Batch 20 | Training loss 0.0760 | Running time 25.14s
# Batch 25 | Training loss 0.0812 | Running time 24.80s
#
# Summary:
# 	Validation acc: 94.40% (at an 80% threshold)
# 	Validation loss: 0.0770
# 	Epoch running time: 168.54s
# Saving `last` model weights at epoch 29
# Previous `best` weights recorded at epoch 20
#
#
# Epoch 30
# --------
# Batch 00 | Training loss 0.0285 | Running time 5.23s
# Batch 05 | Training loss 0.0586 | Running time 25.69s
# Batch 10 | Training loss 0.0464 | Running time 25.53s
# Batch 15 | Training loss 0.0819 | Running time 25.62s
# Batch 20 | Training loss 0.0209 | Running time 24.45s
# Batch 25 | Training loss 0.0711 | Running time 25.66s
#
# Summary:
# 	Validation acc: 96.98% (at an 80% threshold)
# 	Validation loss: 0.0302
# 	Epoch running time: 174.24s
# Saving `last` model weights at epoch 30
# * Saving `best` model weights at epoch 30 *
#
#
# Epoch 31
# --------
# Batch 00 | Training loss 0.0591 | Running time 4.93s
# Batch 05 | Training loss 0.0510 | Running time 25.33s
# Batch 10 | Training loss 0.0534 | Running time 25.67s
# Batch 15 | Training loss 0.0910 | Running time 25.73s
# Batch 20 | Training loss 0.0226 | Running time 26.10s
# Batch 25 | Training loss 0.0388 | Running time 25.30s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0249
# 	Epoch running time: 173.13s
# Saving `last` model weights at epoch 31
# * Saving `best` model weights at epoch 31 *
#
#
# Epoch 32
# --------
# Batch 00 | Training loss 0.0152 | Running time 5.09s
# Batch 05 | Training loss 0.0385 | Running time 24.33s
# Batch 10 | Training loss 0.0189 | Running time 24.99s
# Batch 15 | Training loss 0.0214 | Running time 25.91s
# Batch 20 | Training loss 0.0515 | Running time 26.64s
# Batch 25 | Training loss 0.0497 | Running time 26.40s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0279
# 	Epoch running time: 173.79s
# Saving `last` model weights at epoch 32
# Previous `best` weights recorded at epoch 31
#
#
# Epoch 33
# --------
# Batch 00 | Training loss 0.0259 | Running time 5.10s
# Batch 05 | Training loss 0.0251 | Running time 25.41s
# Batch 10 | Training loss 0.0607 | Running time 24.56s
# Batch 15 | Training loss 0.0413 | Running time 25.33s
# Batch 20 | Training loss 0.0358 | Running time 24.69s
# Batch 25 | Training loss 0.0300 | Running time 24.51s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0562
# 	Epoch running time: 168.30s
# Saving `last` model weights at epoch 33
# Previous `best` weights recorded at epoch 31
#
#
# Epoch 34
# --------
# Batch 00 | Training loss 0.0059 | Running time 4.99s
# Batch 05 | Training loss 0.0253 | Running time 25.20s
# Batch 10 | Training loss 0.0478 | Running time 25.30s
# Batch 15 | Training loss 0.0409 | Running time 25.09s
# Batch 20 | Training loss 0.0297 | Running time 25.40s
# Batch 25 | Training loss 0.0843 | Running time 24.78s
#
# Summary:
# 	Validation acc: 96.12% (at an 80% threshold)
# 	Validation loss: 0.0478
# 	Epoch running time: 167.24s
# Saving `last` model weights at epoch 34
# Previous `best` weights recorded at epoch 31
#
#
# Epoch 35
# --------
# Batch 00 | Training loss 0.0197 | Running time 5.29s
# Batch 05 | Training loss 0.0241 | Running time 26.40s
# Batch 10 | Training loss 0.0265 | Running time 25.83s
# Batch 15 | Training loss 0.0288 | Running time 25.19s
# Batch 20 | Training loss 0.0380 | Running time 24.54s
# Batch 25 | Training loss 0.0148 | Running time 24.72s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0244
# 	Epoch running time: 167.79s
# Saving `last` model weights at epoch 35
# * Saving `best` model weights at epoch 35 *
#
#
# Epoch 36
# --------
# Batch 00 | Training loss 0.0290 | Running time 5.21s
# Batch 05 | Training loss 0.0237 | Running time 25.48s
# Batch 10 | Training loss 0.0226 | Running time 24.42s
# Batch 15 | Training loss 0.0057 | Running time 25.34s
# Batch 20 | Training loss 0.0332 | Running time 25.03s
# Batch 25 | Training loss 0.0142 | Running time 25.19s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0875
# 	Epoch running time: 170.61s
# Saving `last` model weights at epoch 36
# Previous `best` weights recorded at epoch 35
#
#
# Epoch 37
# --------
# Batch 00 | Training loss 0.0051 | Running time 5.02s
# Batch 05 | Training loss 0.0176 | Running time 25.43s
# Batch 10 | Training loss 0.1389 | Running time 24.96s
# Batch 15 | Training loss 0.0443 | Running time 24.54s
# Batch 20 | Training loss 0.0269 | Running time 24.38s
# Batch 25 | Training loss 0.0544 | Running time 24.85s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0452
# 	Epoch running time: 165.37s
# Saving `last` model weights at epoch 37
# Previous `best` weights recorded at epoch 35
#
#
# Epoch 38
# --------
# Batch 00 | Training loss 0.0494 | Running time 4.84s
# Batch 05 | Training loss 0.0115 | Running time 25.71s
# Batch 10 | Training loss 0.0349 | Running time 25.54s
# Batch 15 | Training loss 0.0529 | Running time 25.93s
# Batch 20 | Training loss 0.0168 | Running time 24.95s
# Batch 25 | Training loss 0.0385 | Running time 25.49s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0380
# 	Epoch running time: 171.74s
# Saving `last` model weights at epoch 38
# Previous `best` weights recorded at epoch 35
#
#
# Epoch 39
# --------
# Batch 00 | Training loss 0.0101 | Running time 5.21s
# Batch 05 | Training loss 0.0347 | Running time 25.83s
# Batch 10 | Training loss 0.0175 | Running time 25.91s
# Batch 15 | Training loss 0.0181 | Running time 26.03s
# Batch 20 | Training loss 0.0314 | Running time 25.34s
# Batch 25 | Training loss 0.0088 | Running time 25.17s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0234
# 	Epoch running time: 170.09s
# Saving `last` model weights at epoch 39
# * Saving `best` model weights at epoch 39 *
#
#
# Epoch 40
# --------
# Batch 00 | Training loss 0.1264 | Running time 4.83s
# Batch 05 | Training loss 0.0357 | Running time 24.70s
# Batch 10 | Training loss 0.0409 | Running time 25.39s
# Batch 15 | Training loss 0.0256 | Running time 24.85s
# Batch 20 | Training loss 0.0169 | Running time 25.41s
# Batch 25 | Training loss 0.0278 | Running time 25.87s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0424
# 	Epoch running time: 167.56s
# Saving `last` model weights at epoch 40
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 41
# --------
# Batch 00 | Training loss 0.0498 | Running time 4.84s
# Batch 05 | Training loss 0.0168 | Running time 24.80s
# Batch 10 | Training loss 0.0202 | Running time 24.81s
# Batch 15 | Training loss 0.0208 | Running time 25.14s
# Batch 20 | Training loss 0.0202 | Running time 24.66s
# Batch 25 | Training loss 0.0210 | Running time 25.56s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0285
# 	Epoch running time: 170.73s
# Saving `last` model weights at epoch 41
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 42
# --------
# Batch 00 | Training loss 0.0127 | Running time 4.87s
# Batch 05 | Training loss 0.0212 | Running time 25.73s
# Batch 10 | Training loss 0.0085 | Running time 25.63s
# Batch 15 | Training loss 0.0056 | Running time 24.79s
# Batch 20 | Training loss 0.0216 | Running time 25.84s
# Batch 25 | Training loss 0.0127 | Running time 25.09s
#
# Summary:
# 	Validation acc: 97.41% (at an 80% threshold)
# 	Validation loss: 0.0416
# 	Epoch running time: 171.48s
# Saving `last` model weights at epoch 42
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 43
# --------
# Batch 00 | Training loss 0.0207 | Running time 4.99s
# Batch 05 | Training loss 0.0095 | Running time 24.91s
# Batch 10 | Training loss 0.0164 | Running time 25.85s
# Batch 15 | Training loss 0.0149 | Running time 25.11s
# Batch 20 | Training loss 0.0352 | Running time 25.23s
# Batch 25 | Training loss 0.0304 | Running time 24.92s
#
# Summary:
# 	Validation acc: 99.14% (at an 80% threshold)
# 	Validation loss: 0.0295
# 	Epoch running time: 171.88s
# Saving `last` model weights at epoch 43
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 44
# --------
# Batch 00 | Training loss 0.0031 | Running time 5.14s
# Batch 05 | Training loss 0.0491 | Running time 26.16s
# Batch 10 | Training loss 0.0467 | Running time 25.25s
# Batch 15 | Training loss 0.0432 | Running time 24.37s
# Batch 20 | Training loss 0.0180 | Running time 25.76s
# Batch 25 | Training loss 0.0760 | Running time 24.51s
#
# Summary:
# 	Validation acc: 93.53% (at an 80% threshold)
# 	Validation loss: 0.0933
# 	Epoch running time: 170.70s
# Saving `last` model weights at epoch 44
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 45
# --------
# Batch 00 | Training loss 0.1212 | Running time 4.86s
# Batch 05 | Training loss 0.0579 | Running time 25.17s
# Batch 10 | Training loss 0.0380 | Running time 24.50s
# Batch 15 | Training loss 0.0249 | Running time 25.64s
# Batch 20 | Training loss 0.0226 | Running time 25.67s
# Batch 25 | Training loss 0.0144 | Running time 25.02s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0581
# 	Epoch running time: 171.29s
# Saving `last` model weights at epoch 45
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 46
# --------
# Batch 00 | Training loss 0.0534 | Running time 4.93s
# Batch 05 | Training loss 0.0420 | Running time 25.70s
# Batch 10 | Training loss 0.0247 | Running time 25.77s
# Batch 15 | Training loss 0.0125 | Running time 24.92s
# Batch 20 | Training loss 0.0145 | Running time 26.05s
# Batch 25 | Training loss 0.0246 | Running time 24.96s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0495
# 	Epoch running time: 171.45s
# Saving `last` model weights at epoch 46
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 47
# --------
# Batch 00 | Training loss 0.0032 | Running time 5.00s
# Batch 05 | Training loss 0.0349 | Running time 25.90s
# Batch 10 | Training loss 0.0203 | Running time 25.18s
# Batch 15 | Training loss 0.0309 | Running time 25.97s
# Batch 20 | Training loss 0.0296 | Running time 24.97s
# Batch 25 | Training loss 0.0205 | Running time 24.67s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0320
# 	Epoch running time: 172.29s
# Saving `last` model weights at epoch 47
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 48
# --------
# Batch 00 | Training loss 0.0024 | Running time 5.04s
# Batch 05 | Training loss 0.0103 | Running time 25.61s
# Batch 10 | Training loss 0.0225 | Running time 26.06s
# Batch 15 | Training loss 0.0113 | Running time 25.41s
# Batch 20 | Training loss 0.0258 | Running time 24.78s
# Batch 25 | Training loss 0.0091 | Running time 24.83s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0414
# 	Epoch running time: 167.89s
# Saving `last` model weights at epoch 48
# Previous `best` weights recorded at epoch 39
#
#
# Epoch 49
# --------
# Batch 00 | Training loss 0.0193 | Running time 4.82s
# Batch 05 | Training loss 0.0185 | Running time 24.93s
# Batch 10 | Training loss 0.0070 | Running time 25.19s
# Batch 15 | Training loss 0.0116 | Running time 25.54s
# Batch 20 | Training loss 0.0321 | Running time 25.01s
# Batch 25 | Training loss 0.0482 | Running time 25.39s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0189
# 	Epoch running time: 171.47s
# Saving `last` model weights at epoch 49
# * Saving `best` model weights at epoch 49 *
#
#
# Epoch 50
# --------
# Batch 00 | Training loss 0.0066 | Running time 4.88s
# Batch 05 | Training loss 0.0325 | Running time 25.00s
# Batch 10 | Training loss 0.0363 | Running time 25.63s
# Batch 15 | Training loss 0.0124 | Running time 24.63s
# Batch 20 | Training loss 0.0124 | Running time 25.59s
# Batch 25 | Training loss 0.0106 | Running time 24.88s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0374
# 	Epoch running time: 169.46s
# Saving `last` model weights at epoch 50
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 51
# --------
# Batch 00 | Training loss 0.0014 | Running time 4.93s
# Batch 05 | Training loss 0.0163 | Running time 26.05s
# Batch 10 | Training loss 0.0076 | Running time 25.74s
# Batch 15 | Training loss 0.0052 | Running time 24.74s
# Batch 20 | Training loss 0.0139 | Running time 25.30s
# Batch 25 | Training loss 0.0072 | Running time 26.01s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0213
# 	Epoch running time: 173.55s
# Saving `last` model weights at epoch 51
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 52
# --------
# Batch 00 | Training loss 0.0066 | Running time 4.93s
# Batch 05 | Training loss 0.0059 | Running time 24.91s
# Batch 10 | Training loss 0.0027 | Running time 25.48s
# Batch 15 | Training loss 0.0027 | Running time 24.87s
# Batch 20 | Training loss 0.0030 | Running time 25.48s
# Batch 25 | Training loss 0.0019 | Running time 25.38s
#
# Summary:
# 	Validation acc: 99.14% (at an 80% threshold)
# 	Validation loss: 0.0408
# 	Epoch running time: 170.45s
# Saving `last` model weights at epoch 52
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 53
# --------
# Batch 00 | Training loss 0.0002 | Running time 5.00s
# Batch 05 | Training loss 0.0062 | Running time 24.45s
# Batch 10 | Training loss 0.0063 | Running time 25.30s
# Batch 15 | Training loss 0.0078 | Running time 25.07s
# Batch 20 | Training loss 0.0092 | Running time 25.25s
# Batch 25 | Training loss 0.0294 | Running time 25.21s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0349
# 	Epoch running time: 167.03s
# Saving `last` model weights at epoch 53
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 54
# --------
# Batch 00 | Training loss 0.0054 | Running time 4.96s
# Batch 05 | Training loss 0.0219 | Running time 26.04s
# Batch 10 | Training loss 0.0093 | Running time 25.17s
# Batch 15 | Training loss 0.0126 | Running time 25.25s
# Batch 20 | Training loss 0.0554 | Running time 25.28s
# Batch 25 | Training loss 0.0186 | Running time 24.82s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0752
# 	Epoch running time: 170.87s
# Saving `last` model weights at epoch 54
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 55
# --------
# Batch 00 | Training loss 0.0054 | Running time 4.97s
# Batch 05 | Training loss 0.0215 | Running time 25.32s
# Batch 10 | Training loss 0.0213 | Running time 24.47s
# Batch 15 | Training loss 0.0221 | Running time 24.44s
# Batch 20 | Training loss 0.0100 | Running time 25.14s
# Batch 25 | Training loss 0.0120 | Running time 25.17s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0493
# 	Epoch running time: 168.97s
# Saving `last` model weights at epoch 55
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 56
# --------
# Batch 00 | Training loss 0.0010 | Running time 4.89s
# Batch 05 | Training loss 0.0155 | Running time 25.06s
# Batch 10 | Training loss 0.0194 | Running time 26.06s
# Batch 15 | Training loss 0.0043 | Running time 25.35s
# Batch 20 | Training loss 0.0160 | Running time 25.45s
# Batch 25 | Training loss 0.0199 | Running time 25.49s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0866
# 	Epoch running time: 172.16s
# Saving `last` model weights at epoch 56
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 57
# --------
# Batch 00 | Training loss 0.0920 | Running time 4.93s
# Batch 05 | Training loss 0.0142 | Running time 25.62s
# Batch 10 | Training loss 0.0308 | Running time 24.75s
# Batch 15 | Training loss 0.0060 | Running time 25.43s
# Batch 20 | Training loss 0.0176 | Running time 25.77s
# Batch 25 | Training loss 0.0025 | Running time 25.72s
#
# Summary:
# 	Validation acc: 97.41% (at an 80% threshold)
# 	Validation loss: 0.0975
# 	Epoch running time: 168.51s
# Saving `last` model weights at epoch 57
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 58
# --------
# Batch 00 | Training loss 0.0008 | Running time 4.87s
# Batch 05 | Training loss 0.0327 | Running time 25.61s
# Batch 10 | Training loss 0.0154 | Running time 24.72s
# Batch 15 | Training loss 0.0079 | Running time 24.40s
# Batch 20 | Training loss 0.0093 | Running time 25.52s
# Batch 25 | Training loss 0.0460 | Running time 25.72s
#
# Summary:
# 	Validation acc: 96.98% (at an 80% threshold)
# 	Validation loss: 0.0347
# 	Epoch running time: 168.86s
# Saving `last` model weights at epoch 58
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 59
# --------
# Batch 00 | Training loss 0.0475 | Running time 4.97s
# Batch 05 | Training loss 0.0144 | Running time 25.47s
# Batch 10 | Training loss 0.0308 | Running time 25.61s
# Batch 15 | Training loss 0.0192 | Running time 25.27s
# Batch 20 | Training loss 0.0536 | Running time 25.03s
# Batch 25 | Training loss 0.0289 | Running time 24.28s
#
# Summary:
# 	Validation acc: 97.41% (at an 80% threshold)
# 	Validation loss: 0.0469
# 	Epoch running time: 170.38s
# Saving `last` model weights at epoch 59
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 60
# --------
# Batch 00 | Training loss 0.0240 | Running time 4.82s
# Batch 05 | Training loss 0.0305 | Running time 24.31s
# Batch 10 | Training loss 0.0303 | Running time 25.15s
# Batch 15 | Training loss 0.0452 | Running time 24.34s
# Batch 20 | Training loss 0.0398 | Running time 25.16s
# Batch 25 | Training loss 0.0290 | Running time 25.01s
#
# Summary:
# 	Validation acc: 96.98% (at an 80% threshold)
# 	Validation loss: 0.0591
# 	Epoch running time: 168.26s
# Saving `last` model weights at epoch 60
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 61
# --------
# Batch 00 | Training loss 0.0656 | Running time 5.14s
# Batch 05 | Training loss 0.0250 | Running time 25.83s
# Batch 10 | Training loss 0.0435 | Running time 25.78s
# Batch 15 | Training loss 0.0232 | Running time 25.63s
# Batch 20 | Training loss 0.0170 | Running time 25.70s
# Batch 25 | Training loss 0.0086 | Running time 26.79s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0370
# 	Epoch running time: 175.11s
# Saving `last` model weights at epoch 61
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 62
# --------
# Batch 00 | Training loss 0.0013 | Running time 4.88s
# Batch 05 | Training loss 0.0149 | Running time 25.10s
# Batch 10 | Training loss 0.0052 | Running time 26.41s
# Batch 15 | Training loss 0.0033 | Running time 25.97s
# Batch 20 | Training loss 0.0149 | Running time 25.46s
# Batch 25 | Training loss 0.0087 | Running time 26.12s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0606
# 	Epoch running time: 175.47s
# Saving `last` model weights at epoch 62
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 63
# --------
# Batch 00 | Training loss 0.0019 | Running time 4.98s
# Batch 05 | Training loss 0.0666 | Running time 25.58s
# Batch 10 | Training loss 0.0175 | Running time 25.60s
# Batch 15 | Training loss 0.0232 | Running time 26.12s
# Batch 20 | Training loss 0.0248 | Running time 25.20s
# Batch 25 | Training loss 0.0172 | Running time 24.94s
#
# Summary:
# 	Validation acc: 97.41% (at an 80% threshold)
# 	Validation loss: 0.0528
# 	Epoch running time: 169.31s
# Saving `last` model weights at epoch 63
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 64
# --------
# Batch 00 | Training loss 0.0051 | Running time 5.27s
# Batch 05 | Training loss 0.0263 | Running time 25.56s
# Batch 10 | Training loss 0.0203 | Running time 24.83s
# Batch 15 | Training loss 0.0035 | Running time 24.58s
# Batch 20 | Training loss 0.0068 | Running time 25.04s
# Batch 25 | Training loss 0.0036 | Running time 25.08s
#
# Summary:
# 	Validation acc: 98.28% (at an 80% threshold)
# 	Validation loss: 0.0357
# 	Epoch running time: 166.89s
# Saving `last` model weights at epoch 64
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 65
# --------
# Batch 00 | Training loss 0.0025 | Running time 4.90s
# Batch 05 | Training loss 0.0074 | Running time 25.69s
# Batch 10 | Training loss 0.0019 | Running time 24.97s
# Batch 15 | Training loss 0.0127 | Running time 25.99s
# Batch 20 | Training loss 0.0192 | Running time 25.31s
# Batch 25 | Training loss 0.0241 | Running time 25.07s
#
# Summary:
# 	Validation acc: 97.84% (at an 80% threshold)
# 	Validation loss: 0.0878
# 	Epoch running time: 173.30s
# Saving `last` model weights at epoch 65
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 66
# --------
# Batch 00 | Training loss 0.0006 | Running time 4.90s
# Batch 05 | Training loss 0.0127 | Running time 25.05s
# Batch 10 | Training loss 0.0168 | Running time 25.78s
# Batch 15 | Training loss 0.0269 | Running time 24.80s
# Batch 20 | Training loss 0.0012 | Running time 26.03s
# Batch 25 | Training loss 0.0160 | Running time 25.08s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0598
# 	Epoch running time: 171.43s
# Saving `last` model weights at epoch 66
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 67
# --------
# Batch 00 | Training loss 0.0187 | Running time 5.25s
# Batch 05 | Training loss 0.0564 | Running time 25.09s
# Batch 10 | Training loss 0.0090 | Running time 24.44s
# Batch 15 | Training loss 0.0121 | Running time 24.78s
# Batch 20 | Training loss 0.0065 | Running time 26.01s
# Batch 25 | Training loss 0.0196 | Running time 25.73s
#
# Summary:
# 	Validation acc: 99.57% (at an 80% threshold)
# 	Validation loss: 0.0358
# 	Epoch running time: 168.15s
# Saving `last` model weights at epoch 67
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 68
# --------
# Batch 00 | Training loss 0.0258 | Running time 5.29s
# Batch 05 | Training loss 0.0022 | Running time 25.26s
# Batch 10 | Training loss 0.0269 | Running time 26.00s
# Batch 15 | Training loss 0.0067 | Running time 26.07s
# Batch 20 | Training loss 0.0117 | Running time 24.79s
# Batch 25 | Training loss 0.0074 | Running time 24.81s
#
# Summary:
# 	Validation acc: 99.14% (at an 80% threshold)
# 	Validation loss: 0.0559
# 	Epoch running time: 170.91s
# Saving `last` model weights at epoch 68
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 69
# --------
# Batch 00 | Training loss 0.0335 | Running time 5.03s
# Batch 05 | Training loss 0.0099 | Running time 25.12s
# Batch 10 | Training loss 0.0064 | Running time 26.00s
# Batch 15 | Training loss 0.0021 | Running time 25.37s
# Batch 20 | Training loss 0.0218 | Running time 24.58s
# Batch 25 | Training loss 0.0056 | Running time 24.69s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0567
# 	Epoch running time: 167.49s
# Saving `last` model weights at epoch 69
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 70
# --------
# Batch 00 | Training loss 0.0018 | Running time 7.45s
# Batch 05 | Training loss 0.0221 | Running time 26.65s
# Batch 10 | Training loss 0.0053 | Running time 25.10s
# Batch 15 | Training loss 0.0200 | Running time 26.31s
# Batch 20 | Training loss 0.0314 | Running time 27.14s
# Batch 25 | Training loss 0.0085 | Running time 25.81s
#
# Summary:
# 	Validation acc: 98.71% (at an 80% threshold)
# 	Validation loss: 0.0495
# 	Epoch running time: 179.44s
# Saving `last` model weights at epoch 70
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 71
# --------
# Batch 00 | Training loss 0.0905 | Running time 5.13s
# Batch 05 | Training loss 0.0118 | Running time 25.46s
# Batch 10 | Training loss 0.0127 | Running time 24.33s
# Batch 15 | Training loss 0.0096 | Running time 24.92s
# Batch 20 | Training loss 0.0064 | Running time 24.73s
# Batch 25 | Training loss 0.0053 | Running time 24.45s
#
# Summary:
# 	Validation acc: 99.57% (at an 80% threshold)
# 	Validation loss: 0.0451
# 	Epoch running time: 167.74s
# Saving `last` model weights at epoch 71
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 72
# --------
# Batch 00 | Training loss 0.0001 | Running time 4.85s
# Batch 05 | Training loss 0.0149 | Running time 25.98s
# Batch 10 | Training loss 0.0043 | Running time 24.52s
# Batch 15 | Training loss 0.0218 | Running time 24.87s
# Batch 20 | Training loss 0.0051 | Running time 25.71s
# Batch 25 | Training loss 0.0152 | Running time 25.33s
#
# Summary:
# 	Validation acc: 99.14% (at an 80% threshold)
# 	Validation loss: 0.0374
# 	Epoch running time: 168.13s
# Saving `last` model weights at epoch 72
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 73
# --------
# Batch 00 | Training loss 0.0068 | Running time 4.90s
# Batch 05 | Training loss 0.0017 | Running time 25.12s
# Batch 10 | Training loss 0.0025 | Running time 24.96s
# Batch 15 | Training loss 0.0097 | Running time 25.88s
# Batch 20 | Training loss 0.0046 | Running time 26.01s
# Batch 25 | Training loss 0.0032 | Running time 25.91s
#
# Summary:
# 	Validation acc: 99.14% (at an 80% threshold)
# 	Validation loss: 0.0401
# 	Epoch running time: 169.83s
# Saving `last` model weights at epoch 73
# Previous `best` weights recorded at epoch 49
#
#
# Epoch 74
# --------
# Batch 00 | Training loss 0.0045 | Running time 5.07s
# Batch 05 | Training loss 0.0121 | Running time 25.53s
# Batch 10 | Training loss 0.0414 | Running time 25.93s
# Batch 15 | Training loss 0.0010 | Running time 25.76s
# Batch 20 | Training loss 0.0183 | Running time 25.92s
# Batch 25 | Training loss 0.0255 | Running time 25.80s
#
# Summary:
# 	Validation acc: 99.57% (at an 80% threshold)
# 	Validation loss: 0.0483
# 	Epoch running time: 173.46s
# Saving `last` model weights at epoch 74
# Previous `best` weights recorded at epoch 49
#
# Final epoch before terminating training: 74
# Finished Training. Best validation loss at epoch: 49

# %% [markdown]
# ## Plot training session statistics

# %%
fig, ax1 = plt.subplots(figsize=(10, 7))
ax2 = ax1.twinx()  # New axis for accuracy plot

# Time axis
xt = np.linspace(1, num_epochs, len(train_loss))
xv = np.linspace(1, num_epochs, int((num_epochs - 1) / epoch_freq) + 1)

# Loss & accuracy plots
tloss, = ax1.plot(xt, train_loss, color='tab:blue', label='Training loss')
vloss, = ax1.plot(
    xv, val_loss, linestyle='dotted', linewidth=3, color='tab:pink',
    label='Validation loss',
)
vacc, = ax2.plot(xv, val_acc, color='tab:green', label='Validation accuracy')

# Best epoch
yb = val_loss[int(best_epoch / epoch_freq)]
yc = val_acc[int(best_epoch / epoch_freq)]
ax1.plot(best_epoch + 1, yb, 'co', markersize=10)
#ax2.plot(best_epoch + 1, yc, 'co')
ax1.annotate('Best epoch: #{}\n Acc: {:.2%}'.format(best_epoch + 1, yc),
               (best_epoch + 1, yb),
               textcoords="offset points", # Where to position text
               xytext=(40, 100), # Distance from text to points (x,y)
               ha='center',
               )

# Axes labels
ax1.set_ylabel('BCE Loss', fontsize=14)
ax2.set_ylabel(
    'Validation acc. @ an {:.0%} threshold'.format(test_threshold), fontsize=14,
)
ax1.set_xlabel('Epoch', fontsize=14)
plt.xlim([1, num_epochs])
ax2.set_ylim(bottom=0., top=1.)
ax1.set_title('Training over {} epochs'.format(num_epochs), fontsize=17)

# Legend
fig.legend(
    [tloss, vloss, vacc],
    ['Training loss',
     'Validation loss',
     'Validation accuracy',
    ],
    loc='center',
    prop={'size': 14}
)

plt.tight_layout()
plt.show()
if save_ok:
    fig.savefig(os.path.join(fig_dir, 'stats.png'))

# %%
fig, ax = plt.subplots(nrows=3, figsize=(7, 8), sharex=True)

# Time axis
xt = np.linspace(1, num_epochs, len(train_loss))
xv = np.linspace(1, num_epochs, int((num_epochs - 1) / epoch_freq) + 1)

# Loss & accuracy plots
ax[0].plot(xt, train_loss, color='tab:blue', label='Training loss')
# ax[1].plot(xv, train_acc, color='tab:orange', label='Training accuracy')
ax[1].plot(
    xv, val_loss, linestyle='dotted', color='tab:pink', label='Validation loss'
)
ax[2].plot(xv, val_acc, color='tab:green', label='Validation accuracy')

# Best epoch
yb = val_loss[int(best_epoch / epoch_freq)]
yc = val_acc[int(best_epoch / epoch_freq)]
# ax[0].plot(best_epoch + 1, train_loss[int(best_epoch / epoch_freq)], 'yo')
# ax[1].plot(best_epoch + 1, train_acc[int(best_epoch / epoch_freq)], 'co')
ax[1].plot(best_epoch + 1, yb, 'co')
ax[2].plot(best_epoch + 1, yc, 'co')
ax[2].annotate('Epoch {}'.format(best_epoch + 1),
               (best_epoch + 1, yb),
               textcoords="offset points", # Where to position text
               xytext=(0, 50), # Distance from text to points (x,y)
               ha='center',
               )

# Axes labels
ax[0].set_ylabel('Training\nLoss')
# ax[1].set_ylabel('Training Acc\n@ {:.0%} threshold'.format(test_threshold))
ax[1].set_ylabel('Validation\nLoss')
ax[2].set_ylabel('ValidationAcc\n@ {:.0%} threshold'.format(test_threshold))
plt.xlabel('Epoch')
plt.xlim([1, num_epochs])
# ax[1].set_ylim(bottom=0., top=1.)
ax[2].set_ylim(bottom=0., top=1.)

# fig.legend()           
plt.tight_layout()
plt.show()
if save_ok:
    fig.savefig(os.path.join(fig_dir, 'split.png'))

# %% [markdown]
# ## Compute trained model performance

# %%
from models.classifier.utils import f1scores

model.load_state_dict(torch.load(best_weights))
f1, f1_thresholds = f1scores(model, val_loader)
# Out:
# Threshold 0.00 | F1 score 0.991
# Threshold 0.05 | F1 score 0.991
# Threshold 0.10 | F1 score 0.991
# Threshold 0.15 | F1 score 0.991
# Threshold 0.20 | F1 score 0.991
# Threshold 0.25 | F1 score 0.991
# Threshold 0.30 | F1 score 0.991
# Threshold 0.35 | F1 score 0.991
# Threshold 0.40 | F1 score 0.991
# Threshold 0.45 | F1 score 0.991
# Threshold 0.50 | F1 score 0.987
# Threshold 0.55 | F1 score 0.987
# Threshold 0.60 | F1 score 0.987
# Threshold 0.65 | F1 score 0.987
# Threshold 0.70 | F1 score 0.987
# Threshold 0.75 | F1 score 0.987
# Threshold 0.80 | F1 score 0.987
# Threshold 0.85 | F1 score 0.983
# Threshold 0.90 | F1 score 0.978
# Threshold 0.95 | F1 score 0.970
# Threshold 1.00 | F1 score 0.004

# %%
from models.classifier.utils import accuracy
acc = accuracy(model, val_loader, thresholds=f1_thresholds, num_classes=2)

# %%
fig, ax = plt.subplots(figsize=(7, 7))

acc_line, = ax.plot(
    f1_thresholds, acc, linewidth=3, linestyle='dotted', color='tab:blue'
)
f1_line, = ax.plot(
    f1_thresholds, f1, linewidth=1, linestyle='solid', color='tab:pink'
)

ax.set_xlabel('Threshold', fontsize=15)
ax.set_title(r'$F_1$ Score and Accuracy vs. Threshold', fontsize=17)

ax.set_xlim(left=0., right=1.)
ax.set_ylim(bottom=0., top=1.)

ax.legend(
    [f1_line, acc_line],
    [r'$F_1 = \frac{2\times(Precision \times Recall)}{Precision + Recall}$',
     'Accuracy'
    ],
    loc='lower center',
    prop={'size': 14}
)

ax.grid(True)
fig.tight_layout()
plt.show()

if save_ok:
    fig.savefig(os.path.join(fig_dir, 'f1-acc.png'))

# %%
fig, ax = plt.subplots(figsize=(7, 7))
f1_line = ax.plot(
    f1_thresholds, f1, linewidth=3, linestyle='solid', color='tab:pink'
)
ax.set_xlabel('Threshold', fontsize=15)
#ax.set_ylabel(
#    r'$F_1 = \frac{2\times(Precision \times Recall)}{Precision + Recall}$',
#    fontsize=18,
#)
ax.set_title(r'$F_1$ Score vs. Acceptance Threshold', fontsize=17)

ax.set_xlim(left=0., right=1.)
ax.set_ylim(bottom=0., top=1.)

ax.legend(
    f1_line,
    [r'$F_1 = \frac{2\times(Precision \times Recall)}{Precision + Recall}$',],
    loc='lower center',
    prop={'size': 18}
)

ax.grid(True)
fig.tight_layout()
plt.show()

if save_ok:
    fig.savefig(os.path.join(fig_dir, 'f1-scores.png'))
