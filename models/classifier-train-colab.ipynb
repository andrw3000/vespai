# %% [markdown]
# # Train a hornet classifier
# We train a deep neurel network to classify our extracted images of hornets.

# %%
# %%bash
# pip install torch==1.10.2
# pip install torchvision==0.11.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.10.2
#   Downloading torch-1.10.2-cp37-cp37m-manylinux1_x86_64.whl (881.9 MB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.2) (4.1.1)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.0+cu113
#     Uninstalling torch-1.12.0+cu113:
#       Successfully uninstalled torch-1.12.0+cu113
# Successfully installed torch-1.10.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchvision==0.11.3
#   Downloading torchvision-0.11.3-cp37-cp37m-manylinux1_x86_64.whl (23.2 MB)
# Requirement already satisfied: torch==1.10.2 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.3) (1.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.3) (1.21.6)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.11.3) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.2->torchvision==0.11.3) (4.1.1)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.0+cu113
#     Uninstalling torchvision-0.13.0+cu113:
#       Successfully uninstalled torchvision-0.13.0+cu113
# Successfully installed torchvision-0.11.3
# tcmalloc: large alloc 1147494400 bytes == 0x38e2e000 @  0x7f22409ad615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.0+cu113 requires torch==1.12.0, but you have torch 1.10.2 which is incompatible.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.10.2 which is incompatible.
# torchaudio 0.12.0+cu113 requires torch==1.12.0, but you have torch 1.10.2 which is incompatible.

# %%
import os
import sys
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

# Magic: automatically reload imports + inline plots
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# Experiment name
exp_name = 'resnet-new-lr001-2'

# Root directory
drive.mount('/content/gdrive', force_remount=True)  # Mount Google Drive
root_dir = '/content/gdrive/MyDrive/Projects/vespai'
sys.path.insert(0, root_dir)
os.chdir(root_dir)
data_dir = os.path.join(root_dir, 'datasets/extracts-21')
weights_dir = os.path.join(
    root_dir, 'models/classifier-runs/' + exp_name + '/weights',
)
os.makedirs(weights_dir, exist_ok=True)

# Save figures
save_ok = True
fig_dir = os.path.join(root_dir, 'models/classifier-runs/' + exp_name + '/figs')
os.makedirs(fig_dir, exist_ok=True)

# Set device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Device: ', device)

# GPU info
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
   print(gpu_info)

# RAM availability
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Mounted at /content/gdrive
# Device:  cuda:0
# Fri Jul 15 11:45:32 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    23W / 300W |      2MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ## Load and prepare the data

# %%
import glob

# Locate data
train_files = glob.glob(os.path.join(data_dir, 'train/*.jpeg'))
val_files = glob.glob(os.path.join(data_dir, 'val/*.jpeg'))
test_files = glob.glob(os.path.join(data_dir, 'test/*.jpeg'))

# %%
# Class names
class_dict = {
     0: 'Vespa crabro',
     1: 'Vespa velutina',
     2: 'Other',
}

# Plot example
rand_file = train_files[np.random.randint(len(train_files), size=1)[0]]
rand_image = cv2.imread(os.path.join(rand_file))  # image.shape = (h, w, c)
rand_image = cv2.cvtColor(rand_image, cv2.COLOR_BGR2RGB)
print('Class: ', int(rand_file[-6]))
print('Class name: ', class_dict[int(rand_file[-6])])

plt.imshow(rand_image)
plt.show()
# Out:
# Class:  0
# Class name:  Vespa crabro

# %% [markdown]
# ### Torch datasets
# Unaugmented example using `HornetDataset` class. From this example below we note that the images need preprocessing to have the same shape and normalisation.

# %%
from models.classifier.loader import HornetDataset

example_set = HornetDataset(train_files)

fig = plt.figure()
for i in range(len(example_set)):
    image, target = example_set[i]
    print('Image shape: ', image.shape) 
    print('Image class: {}'.format(class_dict[int(target[1])]))
    print('\n')
    
    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    plt.imshow(image)

    if i == 3:
        plt.show()
        break
# Out:
# Image shape:  (82, 156, 3)
# Image class: Vespa crabro
#
#
# Image shape:  (149, 140, 3)
# Image class: Vespa velutina
#
#
# Image shape:  (92, 154, 3)
# Image class: Vespa crabro
#
#
# Image shape:  (156, 136, 3)
# Image class: Vespa velutina

# %% [markdown]
# Demonstrate the use of transformations to augment images.

# %%
from models.classifier.loader import Rescale, RandomCrop
from torchvision import transforms

scale = Rescale(256)
crop = RandomCrop(128)
both = transforms.Compose([Rescale(256), RandomCrop(224)])

# Apply each of the above transforms on sample.
sample = example_set[65]
fig = plt.figure()
for i, aug in enumerate([scale, crop, both]):
    aug_sample = aug(sample)
    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(aug).__name__)
    plt.imshow(aug_sample[0])

plt.show()

# %% [markdown]
# ### Construct dataloaders

# %%
from models.classifier.loader import get_hornet_loader
from models.classifier.utils import show_batch

# Get data loaders
train_loader = get_hornet_loader(train_files, batch_size=64, augment=True)
val_loader = get_hornet_loader(val_files, batch_size=1, augment=False)

# Print samples of batches
for idx, sample_batch in enumerate(train_loader):
    print('Batch number ', idx, ', batch size: ', sample_batch[0].size())

    # Observe 4th batch and stop.
    if idx == 3:
        plt.figure(figsize=(12, 12))
        show_batch(sample_batch)
        plt.axis('off')
        plt.ioff()
        plt.savefig(os.path.join(fig_dir, 'augs.png'))
        plt.show()
        break
# Out:
# Batch number  0 , batch size:  torch.Size([64, 3, 256, 256])
# Batch number  1 , batch size:  torch.Size([64, 3, 256, 256])
# Batch number  2 , batch size:  torch.Size([64, 3, 256, 256])
# Batch number  3 , batch size:  torch.Size([64, 3, 256, 256])

# %% [markdown]
# ## Training a classifier network
# We first define a model to classify into either Vespa crabro or Vespa velutina. We don't use `nn.Softmax()` as we seperate binary classifications into the above two classes (one-against-rest) in order to account for examples outside those classes. Probabilities are obtained with the logistic sigmoids `nn.Sigmoid()`. To complement this choice we apply Binary Cross-Entropy loss to the outputs.

# %%
import torch.nn as nn
import torch.nn.functional as F


class BasicNet(nn.Module):
    """Basic convolutional classifier network."""
    
    def __init__(self, num_classes=2):
        super(BasicNet, self).__init__()
        self.norm8 = nn.BatchNorm2d(8)
        self.norm16 = nn.BatchNorm2d(16)
        self.norm32 = nn.BatchNorm2d(32)
        self.conv1 = nn.Conv2d(3, 8, 5, 2, 2)
        self.conv2 = nn.Conv2d(8, 16, 5, 2, 2)
        self.conv3 = nn.Conv2d(16, 32, 5, 2, 2)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(32 * 8 * 8, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, num_classes)
        self.final_activation = nn.Sigmoid()

    def forward(self, x):
        """Forward function expects x.shape = (N, 3, 256, 256)."""
        x = self.conv1(x)  # x.shape = (N, 8, 128, 128)
        x = F.relu(self.norm8(x))
        x = self.conv2(x)  # x.shape = (N, 16, 64, 64)
        x = F.relu(self.norm16(x))
        x = self.pool(x)  # x.shape = (N, 16, 32, 32)
        x = self.conv3(x)  # x.shape = (N, 32, 16, 16)
        x = F.relu(self.norm32(x))
        x = self.pool(x)  # x.shape = (N, 32, 8, 8)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return self.final_activation(x)

# %%
import torch.nn as nn
from torchvision.models import resnet18

class ResNetClassifier(nn.Module):
    """Classifier based on ResNet.
    
    Adapt final ResNet layer `self.resnet.fc` to map to two classes. Activate
    with logisitic sigmoid for uncorrelated binary classification.
    """
    
    def __init__(self, num_classes, use_pretraining=True):
        super(ResNetClassifier, self).__init__()

        # Instantiate model
        self.resnet = resnet18(pretrained=use_pretraining)

        # Bespoke alterations
        self.resnet.fc = nn.Linear(512, num_classes, bias=False)  # New heads
        self.final_activation = nn.Sigmoid() # or nn.Softmax(dim=-1)

    def forward(self, x):
        x = self.resnet(x)
        x = self.final_activation(x)
        return x

# %%
# %%script false
#
# # Print model's state_dict
# print("* Model's state_dict:")
# for param_tensor in model.state_dict():
#     print(param_tensor, "\t", model.state_dict()[param_tensor].size())
#
# print('\n')
#
# # Print optimizer's state_dict
# print("* Optimiser's state_dict:")
# for var_name in optimiser.state_dict():
#     print(var_name, "\t", optimiser.state_dict()[var_name])
#
# # print(model)

# %%
# Instantiate model
model = ResNetClassifier(num_classes=2, use_pretraining=False)
model.eval()

# Save location
last_weights = os.path.join(weights_dir, 'last.pt')
best_weights = os.path.join(weights_dir, 'best.pt')

# Train from previous best weights
resume_weights = False
if os.path.exists(best_weights) and resume_weights:
    model.load_state_dict(torch.load(best_weights))

# %% [markdown]
# ### Training routine

# %%
import time
from tqdm.notebook import tqdm
import torch.optim as optim
from models.classifier.utils import accuracy

num_epochs = 200
epoch_progress_cut_off = 25
learning_rate = 0.001
test_threshold = 0.8
best_epoch = 0

thresholds = torch.linspace(0.5, 0.95, 10)
assert any(thresholds == test_threshold)

# Loss function
criterion = torch.nn.BCELoss()

# Optimiser
# optimiser = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
optimiser = optim.Adam(model.parameters(), lr=learning_rate)

# Record statistics
sub_stats = 5
batch_freq = int(len(train_loader) / sub_stats)  # To print sub-epoch stats
epoch_freq = 1  # Number of epochs on which to validate model
train_loss, val_loss, train_acc, val_acc = [], [], [], []

# Iterate training proceedure
for epoch in tqdm(range(num_epochs)):

    print('\nEpoch {:02d}\n--------'.format(epoch))
    start_time = time.time()
    t0 = start_time

    # Accumulated loss in given epoch
    running_loss = 0.0
    for batch, data in enumerate(train_loader, start=0):
        
        # Perform optimisation step
        images, labels = data  # Retrieve batch data
        optimiser.zero_grad()  # Zero parameter gradients
        outputs = model(images)  # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()  # Backpropagate
        optimiser.step()  # Update gradients
        running_loss += loss.item()  # Record loss

        if batch % batch_freq == 0:

            # Training loss
            if not batch == 0:
                running_loss /= batch_freq
            train_loss.append(running_loss)
            print('Batch {:02d} | Training loss {:00.4f} | Running time {:.2f}s'
                  .format(batch, running_loss, time.time() - t0)
                  )
            t0 = time.time()
            running_loss = 0.0
    
    if epoch % epoch_freq == 0:
        
        # Validation loss
        running_loss = 0.0
        for image, target in val_loader:
            with torch.no_grad():
                prob = model(image)
                running_loss += criterion(prob, target).item()
        val_loss.append(running_loss / len(val_loader))

        # Validation and trianing accuracy
        th_ind = (thresholds == test_threshold)
        val_acc.append(float(accuracy(model, val_loader)[th_ind]))
        # train_acc.append(float(accuracy(model, train_loader)[th_ind]))

        print('\nSummary:\n'
              '\tValidation acc: {:.2%} (at an {:.0%} threshold) \n'
              '\tValidation loss: {:.4f}\n'
              '\tEpoch running time: {:.2f}s'
              .format(val_acc[-1], test_threshold,
                      val_loss[-1],
                      time.time() - start_time,
                      )
        )
        
        # Save last weights
        print(f'Saving `last` model weights at epoch {epoch}')
        torch.save(model.state_dict(), last_weights)

        # Save best weights wrt accuracy
        if epoch == 0 or all(loss > val_loss[-1] for loss in val_loss[:-1]):
            print(f'* Saving `best` model weights at epoch {epoch} *\n')
            torch.save(model.state_dict(), best_weights)
            best_epoch = epoch
        else:
            print(f'Previous `best` weights recorded at epoch {best_epoch}\n')

        if epoch - best_epoch >= epoch_progress_cut_off:
            print(f'Final epoch before terminating training: {epoch}')
            num_epochs = epoch + 1
            break

print(f'Finished Training. Best validation loss at epoch: {best_epoch}')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch 00
# --------
# Batch 00 | Training loss 0.7129 | Running time 4.80s
# Batch 05 | Training loss 2.8600 | Running time 33.43s
# Batch 10 | Training loss 0.6975 | Running time 22.17s
# Batch 15 | Training loss 0.6896 | Running time 22.06s
# Batch 20 | Training loss 0.6917 | Running time 23.84s
# Batch 25 | Training loss 0.6925 | Running time 22.07s
#
# Summary:
# 	Validation acc: 0.00% (at an 80% threshold)
# 	Validation loss: 0.6899
# 	Epoch running time: 164.80s
# Saving `last` model weights at epoch 0
# * Saving `best` model weights at epoch 0 *
#
#
# Epoch 01
# --------
# Batch 00 | Training loss 0.6861 | Running time 4.69s
# Batch 05 | Training loss 0.6743 | Running time 22.25s
# Batch 10 | Training loss 0.6834 | Running time 22.17s
# Batch 15 | Training loss 0.6907 | Running time 21.68s
# Batch 20 | Training loss 0.6936 | Running time 22.51s
# Batch 25 | Training loss 0.6930 | Running time 21.47s
#
# Summary:
# 	Validation acc: 0.00% (at an 80% threshold)
# 	Validation loss: 0.6930
# 	Epoch running time: 149.48s
# Saving `last` model weights at epoch 1
# Previous `best` weights recorded at epoch 0
#
#
# Epoch 02
# --------
# Batch 00 | Training loss 0.6936 | Running time 4.44s
# Batch 05 | Training loss 0.6916 | Running time 23.77s
# Batch 10 | Training loss 0.6885 | Running time 22.00s
# Batch 15 | Training loss 0.6941 | Running time 21.76s
# Batch 20 | Training loss 0.6914 | Running time 22.02s
# Batch 25 | Training loss 0.6919 | Running time 21.93s
#
# Summary:
# 	Validation acc: 0.00% (at an 80% threshold)
# 	Validation loss: 0.6732
# 	Epoch running time: 147.29s
# Saving `last` model weights at epoch 2
# * Saving `best` model weights at epoch 2 *
#
#
# Epoch 03
# --------
# Batch 00 | Training loss 0.6696 | Running time 4.56s
# Batch 05 | Training loss 0.6454 | Running time 22.70s
# Batch 10 | Training loss 0.6802 | Running time 22.07s
# Batch 15 | Training loss 0.6379 | Running time 21.60s
# Batch 20 | Training loss 0.6458 | Running time 22.67s
# Batch 25 | Training loss 0.6542 | Running time 21.17s
#
# Summary:
# 	Validation acc: 0.44% (at an 80% threshold)
# 	Validation loss: 0.6614
# 	Epoch running time: 148.14s
# Saving `last` model weights at epoch 3
# * Saving `best` model weights at epoch 3 *
#
#
# Epoch 04
# --------
# Batch 00 | Training loss 0.6391 | Running time 4.31s
# Batch 05 | Training loss 0.6747 | Running time 22.23s
# Batch 10 | Training loss 0.6432 | Running time 22.57s
# Batch 15 | Training loss 0.6484 | Running time 22.69s
# Batch 20 | Training loss 0.5973 | Running time 22.54s
# Batch 25 | Training loss 0.6064 | Running time 22.16s
#
# Summary:
# 	Validation acc: 24.23% (at an 80% threshold)
# 	Validation loss: 0.5325
# 	Epoch running time: 150.67s
# Saving `last` model weights at epoch 4
# * Saving `best` model weights at epoch 4 *
#
#
# Epoch 05
# --------
# Batch 00 | Training loss 0.5556 | Running time 4.89s
# Batch 05 | Training loss 0.5662 | Running time 23.19s
# Batch 10 | Training loss 0.5533 | Running time 22.66s
# Batch 15 | Training loss 0.5713 | Running time 22.78s
# Batch 20 | Training loss 0.5420 | Running time 21.80s
# Batch 25 | Training loss 0.5056 | Running time 22.79s
#
# Summary:
# 	Validation acc: 55.07% (at an 80% threshold)
# 	Validation loss: 0.3521
# 	Epoch running time: 151.85s
# Saving `last` model weights at epoch 5
# * Saving `best` model weights at epoch 5 *
#
#
# Epoch 06
# --------
# Batch 00 | Training loss 0.5229 | Running time 4.56s
# Batch 05 | Training loss 0.5051 | Running time 22.29s
# Batch 10 | Training loss 0.5663 | Running time 22.16s
# Batch 15 | Training loss 0.5667 | Running time 22.77s
# Batch 20 | Training loss 0.5316 | Running time 22.52s
# Batch 25 | Training loss 0.4753 | Running time 22.51s
#
# Summary:
# 	Validation acc: 62.11% (at an 80% threshold)
# 	Validation loss: 0.3177
# 	Epoch running time: 150.93s
# Saving `last` model weights at epoch 6
# * Saving `best` model weights at epoch 6 *
#
#
# Epoch 07
# --------
# Batch 00 | Training loss 0.4891 | Running time 4.45s
# Batch 05 | Training loss 0.4695 | Running time 23.56s
# Batch 10 | Training loss 0.4856 | Running time 23.38s
# Batch 15 | Training loss 0.4645 | Running time 22.48s
# Batch 20 | Training loss 0.4210 | Running time 22.18s
# Batch 25 | Training loss 0.5292 | Running time 22.35s
#
# Summary:
# 	Validation acc: 60.79% (at an 80% threshold)
# 	Validation loss: 0.3136
# 	Epoch running time: 152.21s
# Saving `last` model weights at epoch 7
# * Saving `best` model weights at epoch 7 *
#
#
# Epoch 08
# --------
# Batch 00 | Training loss 0.4733 | Running time 4.72s
# Batch 05 | Training loss 0.3896 | Running time 22.57s
# Batch 10 | Training loss 0.4687 | Running time 22.31s
# Batch 15 | Training loss 0.4781 | Running time 22.16s
# Batch 20 | Training loss 0.4307 | Running time 23.24s
# Batch 25 | Training loss 0.4123 | Running time 22.42s
#
# Summary:
# 	Validation acc: 63.00% (at an 80% threshold)
# 	Validation loss: 0.2700
# 	Epoch running time: 148.17s
# Saving `last` model weights at epoch 8
# * Saving `best` model weights at epoch 8 *
#
#
# Epoch 09
# --------
# Batch 00 | Training loss 0.4242 | Running time 4.79s
# Batch 05 | Training loss 0.4633 | Running time 22.77s
# Batch 10 | Training loss 0.4384 | Running time 22.35s
# Batch 15 | Training loss 0.4686 | Running time 22.53s
# Batch 20 | Training loss 0.4550 | Running time 22.68s
# Batch 25 | Training loss 0.4184 | Running time 21.98s
#
# Summary:
# 	Validation acc: 50.66% (at an 80% threshold)
# 	Validation loss: 0.2692
# 	Epoch running time: 151.57s
# Saving `last` model weights at epoch 9
# * Saving `best` model weights at epoch 9 *
#
#
# Epoch 10
# --------
# Batch 00 | Training loss 0.5662 | Running time 4.48s
# Batch 05 | Training loss 0.4391 | Running time 23.24s
# Batch 10 | Training loss 0.3995 | Running time 22.15s
# Batch 15 | Training loss 0.3599 | Running time 22.80s
# Batch 20 | Training loss 0.3953 | Running time 23.23s
# Batch 25 | Training loss 0.3621 | Running time 22.42s
#
# Summary:
# 	Validation acc: 75.77% (at an 80% threshold)
# 	Validation loss: 0.2891
# 	Epoch running time: 153.30s
# Saving `last` model weights at epoch 10
# Previous `best` weights recorded at epoch 9
#
#
# Epoch 11
# --------
# Batch 00 | Training loss 0.4962 | Running time 4.77s
# Batch 05 | Training loss 0.5720 | Running time 22.27s
# Batch 10 | Training loss 0.4366 | Running time 22.51s
# Batch 15 | Training loss 0.4312 | Running time 22.68s
# Batch 20 | Training loss 0.4012 | Running time 22.24s
# Batch 25 | Training loss 0.4273 | Running time 21.60s
#
# Summary:
# 	Validation acc: 71.81% (at an 80% threshold)
# 	Validation loss: 0.2549
# 	Epoch running time: 146.74s
# Saving `last` model weights at epoch 11
# * Saving `best` model weights at epoch 11 *
#
#
# Epoch 12
# --------
# Batch 00 | Training loss 0.4298 | Running time 4.51s
# Batch 05 | Training loss 0.3319 | Running time 21.69s
# Batch 10 | Training loss 0.3739 | Running time 22.95s
# Batch 15 | Training loss 0.3557 | Running time 21.92s
# Batch 20 | Training loss 0.3879 | Running time 21.99s
# Batch 25 | Training loss 0.3439 | Running time 21.88s
#
# Summary:
# 	Validation acc: 74.89% (at an 80% threshold)
# 	Validation loss: 0.2535
# 	Epoch running time: 148.70s
# Saving `last` model weights at epoch 12
# * Saving `best` model weights at epoch 12 *
#
#
# Epoch 13
# --------
# Batch 00 | Training loss 0.3649 | Running time 4.76s
# Batch 05 | Training loss 0.3651 | Running time 21.80s
# Batch 10 | Training loss 0.3351 | Running time 23.03s
# Batch 15 | Training loss 0.3441 | Running time 22.62s
# Batch 20 | Training loss 0.3743 | Running time 22.87s
# Batch 25 | Training loss 0.2938 | Running time 23.19s
#
# Summary:
# 	Validation acc: 81.50% (at an 80% threshold)
# 	Validation loss: 0.2222
# 	Epoch running time: 152.41s
# Saving `last` model weights at epoch 13
# * Saving `best` model weights at epoch 13 *
#
#
# Epoch 14
# --------
# Batch 00 | Training loss 0.3761 | Running time 4.37s
# Batch 05 | Training loss 0.3731 | Running time 21.92s
# Batch 10 | Training loss 0.3496 | Running time 21.97s
# Batch 15 | Training loss 0.3402 | Running time 22.74s
# Batch 20 | Training loss 0.2801 | Running time 22.65s
# Batch 25 | Training loss 0.3425 | Running time 22.31s
#
# Summary:
# 	Validation acc: 77.97% (at an 80% threshold)
# 	Validation loss: 0.2253
# 	Epoch running time: 152.65s
# Saving `last` model weights at epoch 14
# Previous `best` weights recorded at epoch 13
#
#
# Epoch 15
# --------
# Batch 00 | Training loss 0.3172 | Running time 4.78s
# Batch 05 | Training loss 0.2585 | Running time 22.43s
# Batch 10 | Training loss 0.3030 | Running time 22.12s
# Batch 15 | Training loss 0.2444 | Running time 22.40s
# Batch 20 | Training loss 0.2767 | Running time 21.97s
# Batch 25 | Training loss 0.2796 | Running time 22.24s
#
# Summary:
# 	Validation acc: 85.90% (at an 80% threshold)
# 	Validation loss: 0.1778
# 	Epoch running time: 148.96s
# Saving `last` model weights at epoch 15
# * Saving `best` model weights at epoch 15 *
#
#
# Epoch 16
# --------
# Batch 00 | Training loss 0.1931 | Running time 4.25s
# Batch 05 | Training loss 0.3016 | Running time 22.19s
# Batch 10 | Training loss 0.2511 | Running time 22.29s
# Batch 15 | Training loss 0.3194 | Running time 22.52s
# Batch 20 | Training loss 0.2383 | Running time 23.11s
# Batch 25 | Training loss 0.3046 | Running time 22.79s
#
# Summary:
# 	Validation acc: 85.46% (at an 80% threshold)
# 	Validation loss: 0.1213
# 	Epoch running time: 149.56s
# Saving `last` model weights at epoch 16
# * Saving `best` model weights at epoch 16 *
#
#
# Epoch 17
# --------
# Batch 00 | Training loss 0.2529 | Running time 4.30s
# Batch 05 | Training loss 0.2377 | Running time 21.86s
# Batch 10 | Training loss 0.2264 | Running time 21.67s
# Batch 15 | Training loss 0.2268 | Running time 22.87s
# Batch 20 | Training loss 0.1944 | Running time 21.25s
# Batch 25 | Training loss 0.1858 | Running time 22.32s
#
# Summary:
# 	Validation acc: 95.59% (at an 80% threshold)
# 	Validation loss: 0.0679
# 	Epoch running time: 147.70s
# Saving `last` model weights at epoch 17
# * Saving `best` model weights at epoch 17 *
#
#
# Epoch 18
# --------
# Batch 00 | Training loss 0.1107 | Running time 4.50s
# Batch 05 | Training loss 0.1495 | Running time 22.85s
# Batch 10 | Training loss 0.1729 | Running time 22.34s
# Batch 15 | Training loss 0.1711 | Running time 22.19s
# Batch 20 | Training loss 0.1774 | Running time 22.12s
# Batch 25 | Training loss 0.1620 | Running time 21.96s
#
# Summary:
# 	Validation acc: 96.92% (at an 80% threshold)
# 	Validation loss: 0.0535
# 	Epoch running time: 151.10s
# Saving `last` model weights at epoch 18
# * Saving `best` model weights at epoch 18 *
#
#
# Epoch 19
# --------
# Batch 00 | Training loss 0.2926 | Running time 4.39s
# Batch 05 | Training loss 0.1872 | Running time 21.69s
# Batch 10 | Training loss 0.1618 | Running time 21.62s
# Batch 15 | Training loss 0.2193 | Running time 21.45s
# Batch 20 | Training loss 0.1491 | Running time 22.12s
# Batch 25 | Training loss 0.1657 | Running time 21.88s
#
# Summary:
# 	Validation acc: 88.99% (at an 80% threshold)
# 	Validation loss: 0.1106
# 	Epoch running time: 149.21s
# Saving `last` model weights at epoch 19
# Previous `best` weights recorded at epoch 18
#
#
# Epoch 20
# --------
# Batch 00 | Training loss 0.3929 | Running time 4.38s
# Batch 05 | Training loss 0.1475 | Running time 21.97s
# Batch 10 | Training loss 0.1654 | Running time 22.46s
# Batch 15 | Training loss 0.1238 | Running time 21.73s
# Batch 20 | Training loss 0.1197 | Running time 21.61s
# Batch 25 | Training loss 0.1648 | Running time 22.28s
#
# Summary:
# 	Validation acc: 93.83% (at an 80% threshold)
# 	Validation loss: 0.0701
# 	Epoch running time: 147.59s
# Saving `last` model weights at epoch 20
# Previous `best` weights recorded at epoch 18
#
#
# Epoch 21
# --------
# Batch 00 | Training loss 0.2071 | Running time 4.41s
# Batch 05 | Training loss 0.1962 | Running time 22.56s
# Batch 10 | Training loss 0.1502 | Running time 21.62s
# Batch 15 | Training loss 0.2197 | Running time 22.36s
# Batch 20 | Training loss 0.1955 | Running time 22.14s
# Batch 25 | Training loss 0.1485 | Running time 21.81s
#
# Summary:
# 	Validation acc: 98.68% (at an 80% threshold)
# 	Validation loss: 0.0368
# 	Epoch running time: 148.93s
# Saving `last` model weights at epoch 21
# * Saving `best` model weights at epoch 21 *
#
#
# Epoch 22
# --------
# Batch 00 | Training loss 0.1298 | Running time 4.44s
# Batch 05 | Training loss 0.1253 | Running time 23.59s
# Batch 10 | Training loss 0.1058 | Running time 21.92s
# Batch 15 | Training loss 0.0921 | Running time 22.13s
# Batch 20 | Training loss 0.0955 | Running time 24.05s
# Batch 25 | Training loss 0.0991 | Running time 23.96s
#
# Summary:
# 	Validation acc: 96.92% (at an 80% threshold)
# 	Validation loss: 0.0275
# 	Epoch running time: 154.30s
# Saving `last` model weights at epoch 22
# * Saving `best` model weights at epoch 22 *
#
#
# Epoch 23
# --------
# Batch 00 | Training loss 0.0805 | Running time 4.46s
# Batch 05 | Training loss 0.0937 | Running time 22.41s
# Batch 10 | Training loss 0.0618 | Running time 22.15s
# Batch 15 | Training loss 0.0972 | Running time 22.00s
# Batch 20 | Training loss 0.0738 | Running time 21.48s
# Batch 25 | Training loss 0.0993 | Running time 28.05s
#
# Summary:
# 	Validation acc: 99.12% (at an 80% threshold)
# 	Validation loss: 0.0125
# 	Epoch running time: 155.74s
# Saving `last` model weights at epoch 23
# * Saving `best` model weights at epoch 23 *
#
#
# Epoch 24
# --------
# Batch 00 | Training loss 0.1531 | Running time 4.34s
# Batch 05 | Training loss 0.0869 | Running time 22.87s
# Batch 10 | Training loss 0.0927 | Running time 22.60s
# Batch 15 | Training loss 0.1422 | Running time 21.78s
# Batch 20 | Training loss 0.1027 | Running time 22.08s
# Batch 25 | Training loss 0.1288 | Running time 22.74s
#
# Summary:
# 	Validation acc: 96.04% (at an 80% threshold)
# 	Validation loss: 0.0492
# 	Epoch running time: 151.87s
# Saving `last` model weights at epoch 24
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 25
# --------
# Batch 00 | Training loss 0.0694 | Running time 5.83s
# Batch 05 | Training loss 0.1306 | Running time 23.58s
# Batch 10 | Training loss 0.1134 | Running time 21.92s
# Batch 15 | Training loss 0.1119 | Running time 23.46s
# Batch 20 | Training loss 0.0619 | Running time 22.71s
# Batch 25 | Training loss 0.0786 | Running time 22.07s
#
# Summary:
# 	Validation acc: 98.68% (at an 80% threshold)
# 	Validation loss: 0.0128
# 	Epoch running time: 152.90s
# Saving `last` model weights at epoch 25
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 26
# --------
# Batch 00 | Training loss 0.2548 | Running time 4.24s
# Batch 05 | Training loss 0.0704 | Running time 23.42s
# Batch 10 | Training loss 0.0965 | Running time 21.85s
# Batch 15 | Training loss 0.1357 | Running time 21.85s
# Batch 20 | Training loss 0.1430 | Running time 21.78s
# Batch 25 | Training loss 0.0903 | Running time 21.89s
#
# Summary:
# 	Validation acc: 93.39% (at an 80% threshold)
# 	Validation loss: 0.0460
# 	Epoch running time: 149.31s
# Saving `last` model weights at epoch 26
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 27
# --------
# Batch 00 | Training loss 0.0552 | Running time 4.41s
# Batch 05 | Training loss 0.0939 | Running time 22.18s
# Batch 10 | Training loss 0.0681 | Running time 22.13s
# Batch 15 | Training loss 0.0603 | Running time 21.59s
# Batch 20 | Training loss 0.0573 | Running time 21.75s
# Batch 25 | Training loss 0.1894 | Running time 22.71s
#
# Summary:
# 	Validation acc: 92.07% (at an 80% threshold)
# 	Validation loss: 0.0777
# 	Epoch running time: 148.51s
# Saving `last` model weights at epoch 27
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 28
# --------
# Batch 00 | Training loss 0.2076 | Running time 4.37s
# Batch 05 | Training loss 0.0824 | Running time 22.04s
# Batch 10 | Training loss 0.0923 | Running time 21.91s
# Batch 15 | Training loss 0.0742 | Running time 22.61s
# Batch 20 | Training loss 0.0648 | Running time 22.44s
# Batch 25 | Training loss 0.1162 | Running time 22.14s
#
# Summary:
# 	Validation acc: 94.27% (at an 80% threshold)
# 	Validation loss: 0.0612
# 	Epoch running time: 146.22s
# Saving `last` model weights at epoch 28
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 29
# --------
# Batch 00 | Training loss 0.0418 | Running time 4.47s
# Batch 05 | Training loss 0.0753 | Running time 22.91s
# Batch 10 | Training loss 0.0474 | Running time 22.34s
# Batch 15 | Training loss 0.0447 | Running time 22.53s
# Batch 20 | Training loss 0.0662 | Running time 22.97s
# Batch 25 | Training loss 0.0542 | Running time 21.99s
#
# Summary:
# 	Validation acc: 96.48% (at an 80% threshold)
# 	Validation loss: 0.0321
# 	Epoch running time: 150.76s
# Saving `last` model weights at epoch 29
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 30
# --------
# Batch 00 | Training loss 0.0608 | Running time 4.43s
# Batch 05 | Training loss 0.0828 | Running time 22.06s
# Batch 10 | Training loss 0.0915 | Running time 21.59s
# Batch 15 | Training loss 0.0749 | Running time 22.68s
# Batch 20 | Training loss 0.0980 | Running time 22.94s
# Batch 25 | Training loss 0.2899 | Running time 22.63s
#
# Summary:
# 	Validation acc: 90.31% (at an 80% threshold)
# 	Validation loss: 0.0869
# 	Epoch running time: 150.24s
# Saving `last` model weights at epoch 30
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 31
# --------
# Batch 00 | Training loss 0.1499 | Running time 4.48s
# Batch 05 | Training loss 0.1138 | Running time 22.32s
# Batch 10 | Training loss 0.1015 | Running time 21.78s
# Batch 15 | Training loss 0.0845 | Running time 22.54s
# Batch 20 | Training loss 0.1114 | Running time 22.28s
# Batch 25 | Training loss 0.1001 | Running time 21.97s
#
# Summary:
# 	Validation acc: 95.59% (at an 80% threshold)
# 	Validation loss: 0.0423
# 	Epoch running time: 149.15s
# Saving `last` model weights at epoch 31
# Previous `best` weights recorded at epoch 23
#
#
# Epoch 32
# --------
# Batch 00 | Training loss 0.0852 | Running time 4.48s
# Batch 05 | Training loss 0.0462 | Running time 26.56s
# Batch 10 | Training loss 0.0556 | Running time 22.14s
# Batch 15 | Training loss 0.0395 | Running time 22.98s
# Batch 20 | Training loss 0.0512 | Running time 22.83s
# Batch 25 | Training loss 0.0512 | Running time 21.95s
#
# Summary:
# 	Validation acc: 100.00% (at an 80% threshold)
# 	Validation loss: 0.0037
# 	Epoch running time: 154.27s
# Saving `last` model weights at epoch 32
# * Saving `best` model weights at epoch 32 *
#
#
# Epoch 33
# --------
# Batch 00 | Training loss 0.0309 | Running time 4.37s
# Batch 05 | Training loss 0.0953 | Running time 22.28s
# Batch 10 | Training loss 0.0428 | Running time 22.11s
# Batch 15 | Training loss 0.0594 | Running time 21.27s
# Batch 20 | Training loss 0.0325 | Running time 23.15s
# Batch 25 | Training loss 0.0272 | Running time 22.51s
#
# Summary:
# 	Validation acc: 98.68% (at an 80% threshold)
# 	Validation loss: 0.0083
# 	Epoch running time: 147.68s
# Saving `last` model weights at epoch 33
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 34
# --------
# Batch 00 | Training loss 0.0049 | Running time 4.51s
# Batch 05 | Training loss 0.0222 | Running time 22.34s
# Batch 10 | Training loss 0.0265 | Running time 21.63s
# Batch 15 | Training loss 0.0110 | Running time 23.85s
# Batch 20 | Training loss 0.0777 | Running time 22.62s
# Batch 25 | Training loss 0.0587 | Running time 21.76s
#
# Summary:
# 	Validation acc: 97.36% (at an 80% threshold)
# 	Validation loss: 0.0280
# 	Epoch running time: 150.13s
# Saving `last` model weights at epoch 34
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 35
# --------
# Batch 00 | Training loss 0.0451 | Running time 4.43s
# Batch 05 | Training loss 0.0434 | Running time 22.72s
# Batch 10 | Training loss 0.0484 | Running time 22.46s
# Batch 15 | Training loss 0.0588 | Running time 22.00s
# Batch 20 | Training loss 0.0358 | Running time 21.96s
# Batch 25 | Training loss 0.0209 | Running time 22.49s
#
# Summary:
# 	Validation acc: 98.68% (at an 80% threshold)
# 	Validation loss: 0.0168
# 	Epoch running time: 151.57s
# Saving `last` model weights at epoch 35
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 36
# --------
# Batch 00 | Training loss 0.0271 | Running time 4.69s
# Batch 05 | Training loss 0.0466 | Running time 22.65s
# Batch 10 | Training loss 0.0482 | Running time 21.71s
# Batch 15 | Training loss 0.0499 | Running time 22.32s
# Batch 20 | Training loss 0.0593 | Running time 22.44s
# Batch 25 | Training loss 0.0183 | Running time 23.15s
#
# Summary:
# 	Validation acc: 97.36% (at an 80% threshold)
# 	Validation loss: 0.0304
# 	Epoch running time: 147.99s
# Saving `last` model weights at epoch 36
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 37
# --------
# Batch 00 | Training loss 0.0508 | Running time 4.48s
# Batch 05 | Training loss 0.0143 | Running time 22.08s
# Batch 10 | Training loss 0.0125 | Running time 22.67s
# Batch 15 | Training loss 0.0535 | Running time 22.93s
# Batch 20 | Training loss 0.0632 | Running time 22.40s
# Batch 25 | Training loss 0.1245 | Running time 22.38s
#
# Summary:
# 	Validation acc: 97.36% (at an 80% threshold)
# 	Validation loss: 0.0349
# 	Epoch running time: 148.88s
# Saving `last` model weights at epoch 37
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 38
# --------
# Batch 00 | Training loss 0.0678 | Running time 4.68s
# Batch 05 | Training loss 0.1009 | Running time 22.67s
# Batch 10 | Training loss 0.1183 | Running time 23.08s
# Batch 15 | Training loss 0.1316 | Running time 23.32s
# Batch 20 | Training loss 0.0613 | Running time 23.30s
# Batch 25 | Training loss 0.0568 | Running time 23.00s
#
# Summary:
# 	Validation acc: 95.59% (at an 80% threshold)
# 	Validation loss: 0.0351
# 	Epoch running time: 154.81s
# Saving `last` model weights at epoch 38
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 39
# --------
# Batch 00 | Training loss 0.0710 | Running time 4.31s
# Batch 05 | Training loss 0.0407 | Running time 22.53s
# Batch 10 | Training loss 0.0553 | Running time 21.44s
# Batch 15 | Training loss 0.0563 | Running time 21.59s
# Batch 20 | Training loss 0.0407 | Running time 21.38s
# Batch 25 | Training loss 0.0317 | Running time 22.24s
#
# Summary:
# 	Validation acc: 99.12% (at an 80% threshold)
# 	Validation loss: 0.0138
# 	Epoch running time: 146.48s
# Saving `last` model weights at epoch 39
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 40
# --------
# Batch 00 | Training loss 0.0207 | Running time 4.59s
# Batch 05 | Training loss 0.0289 | Running time 22.63s
# Batch 10 | Training loss 0.0437 | Running time 21.88s
# Batch 15 | Training loss 0.0185 | Running time 22.42s
# Batch 20 | Training loss 0.0431 | Running time 23.26s
# Batch 25 | Training loss 0.0306 | Running time 21.55s
#
# Summary:
# 	Validation acc: 98.24% (at an 80% threshold)
# 	Validation loss: 0.0099
# 	Epoch running time: 147.30s
# Saving `last` model weights at epoch 40
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 41
# --------
# Batch 00 | Training loss 0.0374 | Running time 4.28s
# Batch 05 | Training loss 0.0259 | Running time 22.58s
# Batch 10 | Training loss 0.0204 | Running time 21.91s
# Batch 15 | Training loss 0.0392 | Running time 21.54s
# Batch 20 | Training loss 0.0318 | Running time 21.97s
# Batch 25 | Training loss 0.0284 | Running time 21.49s
#
# Summary:
# 	Validation acc: 98.24% (at an 80% threshold)
# 	Validation loss: 0.0143
# 	Epoch running time: 149.01s
# Saving `last` model weights at epoch 41
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 42
# --------
# Batch 00 | Training loss 0.0039 | Running time 4.41s
# Batch 05 | Training loss 0.0142 | Running time 23.26s
# Batch 10 | Training loss 0.0251 | Running time 21.63s
# Batch 15 | Training loss 0.0142 | Running time 21.69s
# Batch 20 | Training loss 0.0332 | Running time 23.15s
# Batch 25 | Training loss 0.0196 | Running time 23.36s
#
# Summary:
# 	Validation acc: 98.24% (at an 80% threshold)
# 	Validation loss: 0.0197
# 	Epoch running time: 148.70s
# Saving `last` model weights at epoch 42
# Previous `best` weights recorded at epoch 32
#
#
# Epoch 43
# --------
# Batch 00 | Training loss 0.0256 | Running time 4.60s
# Batch 05 | Training loss 0.0055 | Running time 25.26s
# Batch 10 | Training loss 0.0193 | Running time 22.84s
# Batch 15 | Training loss 0.0207 | Running time 24.44s
# Batch 20 | Training loss 0.0158 | Running time 23.27s
# Batch 25 | Training loss 0.0053 | Running time 25.03s
#
# Summary:
# 	Validation acc: 100.00% (at an 80% threshold)
# 	Validation loss: 0.0005
# 	Epoch running time: 158.18s
# Saving `last` model weights at epoch 43
# * Saving `best` model weights at epoch 43 *
#
#
# Epoch 44
# --------
# Batch 00 | Training loss 0.0314 | Running time 4.25s
# Batch 05 | Training loss 0.0092 | Running time 21.84s
# Batch 10 | Training loss 0.0192 | Running time 21.82s
# Batch 15 | Training loss 0.0500 | Running time 25.03s
# Batch 20 | Training loss 0.2642 | Running time 33.20s
# Batch 25 | Training loss 0.1113 | Running time 22.54s
#
# Summary:
# 	Validation acc: 92.51% (at an 80% threshold)
# 	Validation loss: 0.0670
# 	Epoch running time: 161.57s
# Saving `last` model weights at epoch 44
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 45
# --------
# Batch 00 | Training loss 0.0737 | Running time 4.42s
# Batch 05 | Training loss 0.0971 | Running time 22.52s
# Batch 10 | Training loss 0.0525 | Running time 22.30s
# Batch 15 | Training loss 0.0368 | Running time 21.49s
# Batch 20 | Training loss 0.0559 | Running time 23.53s
# Batch 25 | Training loss 0.0397 | Running time 22.26s
#
# Summary:
# 	Validation acc: 98.24% (at an 80% threshold)
# 	Validation loss: 0.0243
# 	Epoch running time: 147.35s
# Saving `last` model weights at epoch 45
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 46
# --------
# Batch 00 | Training loss 0.0110 | Running time 4.59s
# Batch 05 | Training loss 0.0350 | Running time 22.12s
# Batch 10 | Training loss 0.0371 | Running time 21.73s
# Batch 15 | Training loss 0.0252 | Running time 22.78s
# Batch 20 | Training loss 0.0257 | Running time 22.02s
# Batch 25 | Training loss 0.0441 | Running time 22.36s
#
# Summary:
# 	Validation acc: 96.48% (at an 80% threshold)
# 	Validation loss: 0.0778
# 	Epoch running time: 148.26s
# Saving `last` model weights at epoch 46
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 47
# --------
# Batch 00 | Training loss 0.0177 | Running time 4.65s
# Batch 05 | Training loss 0.0602 | Running time 24.26s
# Batch 10 | Training loss 0.0614 | Running time 21.17s
# Batch 15 | Training loss 0.0619 | Running time 24.96s
# Batch 20 | Training loss 0.0307 | Running time 22.33s
# Batch 25 | Training loss 0.0136 | Running time 21.75s
#
# Summary:
# 	Validation acc: 98.24% (at an 80% threshold)
# 	Validation loss: 0.0237
# 	Epoch running time: 149.07s
# Saving `last` model weights at epoch 47
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 48
# --------
# Batch 00 | Training loss 0.0026 | Running time 4.43s
# Batch 05 | Training loss 0.0234 | Running time 22.92s
# Batch 10 | Training loss 0.0134 | Running time 22.78s
# Batch 15 | Training loss 0.0245 | Running time 22.54s
# Batch 20 | Training loss 0.0362 | Running time 23.33s
# Batch 25 | Training loss 0.0261 | Running time 21.77s
#
# Summary:
# 	Validation acc: 99.12% (at an 80% threshold)
# 	Validation loss: 0.0098
# 	Epoch running time: 150.94s
# Saving `last` model weights at epoch 48
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 49
# --------
# Batch 00 | Training loss 0.0236 | Running time 4.46s
# Batch 05 | Training loss 0.0222 | Running time 22.38s
# Batch 10 | Training loss 0.0172 | Running time 23.05s
# Batch 15 | Training loss 0.0162 | Running time 22.03s
# Batch 20 | Training loss 0.0399 | Running time 21.79s
# Batch 25 | Training loss 0.0359 | Running time 23.23s
#
# Summary:
# 	Validation acc: 97.80% (at an 80% threshold)
# 	Validation loss: 0.0211
# 	Epoch running time: 151.95s
# Saving `last` model weights at epoch 49
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 50
# --------
# Batch 00 | Training loss 0.0250 | Running time 4.41s
# Batch 05 | Training loss 0.0027 | Running time 23.04s
# Batch 10 | Training loss 0.0087 | Running time 27.31s
# Batch 15 | Training loss 0.0061 | Running time 24.54s
# Batch 20 | Training loss 0.0422 | Running time 26.39s
# Batch 25 | Training loss 0.0554 | Running time 27.22s
#
# Summary:
# 	Validation acc: 99.56% (at an 80% threshold)
# 	Validation loss: 0.0056
# 	Epoch running time: 166.34s
# Saving `last` model weights at epoch 50
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 51
# --------
# Batch 00 | Training loss 0.0112 | Running time 4.27s
# Batch 05 | Training loss 0.0432 | Running time 22.19s
# Batch 10 | Training loss 0.0242 | Running time 23.27s
# Batch 15 | Training loss 0.0431 | Running time 22.72s
# Batch 20 | Training loss 0.0115 | Running time 22.23s
# Batch 25 | Training loss 0.0184 | Running time 23.66s
#
# Summary:
# 	Validation acc: 98.68% (at an 80% threshold)
# 	Validation loss: 0.0076
# 	Epoch running time: 149.16s
# Saving `last` model weights at epoch 51
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 52
# --------
# Batch 00 | Training loss 0.0308 | Running time 4.43s
# Batch 05 | Training loss 0.0055 | Running time 23.47s
# Batch 10 | Training loss 0.0392 | Running time 22.18s
# Batch 15 | Training loss 0.0114 | Running time 22.65s
# Batch 20 | Training loss 0.0066 | Running time 23.52s
# Batch 25 | Training loss 0.0148 | Running time 23.54s
#
# Summary:
# 	Validation acc: 97.80% (at an 80% threshold)
# 	Validation loss: 0.0217
# 	Epoch running time: 153.04s
# Saving `last` model weights at epoch 52
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 53
# --------
# Batch 00 | Training loss 0.0130 | Running time 4.38s
# Batch 05 | Training loss 0.0049 | Running time 23.16s
# Batch 10 | Training loss 0.0222 | Running time 25.05s
# Batch 15 | Training loss 0.0101 | Running time 22.52s
# Batch 20 | Training loss 0.0105 | Running time 24.21s
# Batch 25 | Training loss 0.0155 | Running time 23.46s
#
# Summary:
# 	Validation acc: 99.56% (at an 80% threshold)
# 	Validation loss: 0.0069
# 	Epoch running time: 156.98s
# Saving `last` model weights at epoch 53
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 54
# --------
# Batch 00 | Training loss 0.0008 | Running time 4.62s
# Batch 05 | Training loss 0.1974 | Running time 23.87s
# Batch 10 | Training loss 0.0154 | Running time 21.28s
# Batch 15 | Training loss 0.0226 | Running time 22.32s
# Batch 20 | Training loss 0.0399 | Running time 21.26s
# Batch 25 | Training loss 0.0138 | Running time 22.09s
#
# Summary:
# 	Validation acc: 99.12% (at an 80% threshold)
# 	Validation loss: 0.0067
# 	Epoch running time: 145.53s
# Saving `last` model weights at epoch 54
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 55
# --------
# Batch 00 | Training loss 0.0040 | Running time 4.42s
# Batch 05 | Training loss 0.0045 | Running time 24.34s
# Batch 10 | Training loss 0.2284 | Running time 28.52s
# Batch 15 | Training loss 0.0139 | Running time 23.17s
# Batch 20 | Training loss 0.0495 | Running time 22.63s
# Batch 25 | Training loss 0.0382 | Running time 21.58s
#
# Summary:
# 	Validation acc: 98.24% (at an 80% threshold)
# 	Validation loss: 0.0175
# 	Epoch running time: 158.15s
# Saving `last` model weights at epoch 55
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 56
# --------
# Batch 00 | Training loss 0.0087 | Running time 4.50s
# Batch 05 | Training loss 0.0549 | Running time 22.49s
# Batch 10 | Training loss 0.0126 | Running time 22.56s
# Batch 15 | Training loss 0.0528 | Running time 22.21s
# Batch 20 | Training loss 0.0297 | Running time 23.95s
# Batch 25 | Training loss 0.0412 | Running time 24.33s
#
# Summary:
# 	Validation acc: 97.80% (at an 80% threshold)
# 	Validation loss: 0.0124
# 	Epoch running time: 150.96s
# Saving `last` model weights at epoch 56
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 57
# --------
# Batch 00 | Training loss 0.0179 | Running time 4.68s
# Batch 05 | Training loss 0.0190 | Running time 22.65s
# Batch 10 | Training loss 0.0262 | Running time 21.80s
# Batch 15 | Training loss 0.0446 | Running time 21.89s
# Batch 20 | Training loss 0.0678 | Running time 22.78s
# Batch 25 | Training loss 0.0134 | Running time 22.43s
#
# Summary:
# 	Validation acc: 99.12% (at an 80% threshold)
# 	Validation loss: 0.0163
# 	Epoch running time: 146.42s
# Saving `last` model weights at epoch 57
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 58
# --------
# Batch 00 | Training loss 0.0454 | Running time 4.35s
# Batch 05 | Training loss 0.0405 | Running time 22.14s
# Batch 10 | Training loss 0.0297 | Running time 23.43s
# Batch 15 | Training loss 0.0427 | Running time 23.95s
# Batch 20 | Training loss 0.0627 | Running time 22.50s
# Batch 25 | Training loss 0.0123 | Running time 26.30s
#
# Summary:
# 	Validation acc: 98.68% (at an 80% threshold)
# 	Validation loss: 0.0101
# 	Epoch running time: 153.40s
# Saving `last` model weights at epoch 58
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 59
# --------
# Batch 00 | Training loss 0.1553 | Running time 4.30s
# Batch 05 | Training loss 0.0351 | Running time 23.19s
# Batch 10 | Training loss 0.0139 | Running time 22.45s
# Batch 15 | Training loss 0.0322 | Running time 22.40s
# Batch 20 | Training loss 0.0382 | Running time 24.36s
# Batch 25 | Training loss 0.0353 | Running time 27.64s
#
# Summary:
# 	Validation acc: 99.56% (at an 80% threshold)
# 	Validation loss: 0.0047
# 	Epoch running time: 159.48s
# Saving `last` model weights at epoch 59
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 60
# --------
# Batch 00 | Training loss 0.0195 | Running time 4.39s
# Batch 05 | Training loss 0.0164 | Running time 22.43s
# Batch 10 | Training loss 0.0130 | Running time 22.66s
# Batch 15 | Training loss 0.0203 | Running time 21.28s
# Batch 20 | Training loss 0.0239 | Running time 21.73s
# Batch 25 | Training loss 0.0147 | Running time 22.41s
#
# Summary:
# 	Validation acc: 99.56% (at an 80% threshold)
# 	Validation loss: 0.0038
# 	Epoch running time: 149.36s
# Saving `last` model weights at epoch 60
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 61
# --------
# Batch 00 | Training loss 0.0010 | Running time 4.97s
# Batch 05 | Training loss 0.0211 | Running time 31.70s
# Batch 10 | Training loss 0.0138 | Running time 22.51s
# Batch 15 | Training loss 0.0050 | Running time 22.21s
# Batch 20 | Training loss 0.0324 | Running time 23.80s
# Batch 25 | Training loss 0.0177 | Running time 24.54s
#
# Summary:
# 	Validation acc: 98.68% (at an 80% threshold)
# 	Validation loss: 0.0978
# 	Epoch running time: 163.12s
# Saving `last` model weights at epoch 61
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 62
# --------
# Batch 00 | Training loss 0.0810 | Running time 4.30s
# Batch 05 | Training loss 0.0298 | Running time 25.92s
# Batch 10 | Training loss 0.0181 | Running time 23.74s
# Batch 15 | Training loss 0.0208 | Running time 22.61s
# Batch 20 | Training loss 0.0150 | Running time 21.92s
# Batch 25 | Training loss 0.0106 | Running time 21.23s
#
# Summary:
# 	Validation acc: 100.00% (at an 80% threshold)
# 	Validation loss: 0.0037
# 	Epoch running time: 152.70s
# Saving `last` model weights at epoch 62
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 63
# --------
# Batch 00 | Training loss 0.0055 | Running time 4.16s
# Batch 05 | Training loss 0.0455 | Running time 23.32s
# Batch 10 | Training loss 0.0142 | Running time 22.43s
# Batch 15 | Training loss 0.0213 | Running time 23.02s
# Batch 20 | Training loss 0.0248 | Running time 23.46s
# Batch 25 | Training loss 0.0103 | Running time 24.55s
#
# Summary:
# 	Validation acc: 99.56% (at an 80% threshold)
# 	Validation loss: 0.0054
# 	Epoch running time: 155.95s
# Saving `last` model weights at epoch 63
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 64
# --------
# Batch 00 | Training loss 0.0454 | Running time 4.65s
# Batch 05 | Training loss 0.0070 | Running time 23.37s
# Batch 10 | Training loss 0.0145 | Running time 21.76s
# Batch 15 | Training loss 0.0078 | Running time 23.13s
# Batch 20 | Training loss 0.0050 | Running time 22.00s
# Batch 25 | Training loss 0.0106 | Running time 22.86s
#
# Summary:
# 	Validation acc: 99.56% (at an 80% threshold)
# 	Validation loss: 0.0047
# 	Epoch running time: 150.77s
# Saving `last` model weights at epoch 64
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 65
# --------
# Batch 00 | Training loss 0.0134 | Running time 4.43s
# Batch 05 | Training loss 0.0065 | Running time 22.23s
# Batch 10 | Training loss 0.0038 | Running time 26.19s
# Batch 15 | Training loss 0.0463 | Running time 22.39s
# Batch 20 | Training loss 0.0265 | Running time 23.06s
# Batch 25 | Training loss 0.0104 | Running time 21.44s
#
# Summary:
# 	Validation acc: 100.00% (at an 80% threshold)
# 	Validation loss: 0.0035
# 	Epoch running time: 153.21s
# Saving `last` model weights at epoch 65
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 66
# --------
# Batch 00 | Training loss 0.0266 | Running time 4.52s
# Batch 05 | Training loss 0.0164 | Running time 22.76s
# Batch 10 | Training loss 0.0091 | Running time 22.35s
# Batch 15 | Training loss 0.0090 | Running time 24.31s
# Batch 20 | Training loss 0.0118 | Running time 22.88s
# Batch 25 | Training loss 0.0077 | Running time 25.15s
#
# Summary:
# 	Validation acc: 99.56% (at an 80% threshold)
# 	Validation loss: 0.0019
# 	Epoch running time: 157.46s
# Saving `last` model weights at epoch 66
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 67
# --------
# Batch 00 | Training loss 0.0007 | Running time 4.34s
# Batch 05 | Training loss 0.0063 | Running time 25.00s
# Batch 10 | Training loss 0.0288 | Running time 24.28s
# Batch 15 | Training loss 0.0164 | Running time 26.57s
# Batch 20 | Training loss 0.0128 | Running time 23.78s
# Batch 25 | Training loss 0.0054 | Running time 22.36s
#
# Summary:
# 	Validation acc: 100.00% (at an 80% threshold)
# 	Validation loss: 0.0015
# 	Epoch running time: 159.86s
# Saving `last` model weights at epoch 67
# Previous `best` weights recorded at epoch 43
#
#
# Epoch 68
# --------
# Batch 00 | Training loss 0.0005 | Running time 4.41s
# Batch 05 | Training loss 0.0164 | Running time 23.43s
# Batch 10 | Training loss 0.0409 | Running time 24.26s
# Batch 15 | Training loss 0.0844 | Running time 28.19s
# Batch 20 | Training loss 0.0632 | Running time 22.40s
# Batch 25 | Training loss 0.0609 | Running time 22.95s
#
# Summary:
# 	Validation acc: 98.24% (at an 80% threshold)
# 	Validation loss: 0.0145
# 	Epoch running time: 159.14s
# Saving `last` model weights at epoch 68
# Previous `best` weights recorded at epoch 43
#
# Final epoch before terminating training: 68
# Finished Training. Best validation loss at epoch: 43

# %% [markdown]
# ## Plot training session statistics

# %%
fig, ax1 = plt.subplots(figsize=(10, 7))
ax2 = ax1.twinx()  # New axis for accuracy plot

# Time axis
xt = np.linspace(1, num_epochs, len(train_loss))
xv = np.linspace(1, num_epochs, int((num_epochs - 1) / epoch_freq) + 1)

# Loss & accuracy plots
tloss, = ax1.plot(xt, train_loss, color='tab:blue', label='Training loss')
vloss, = ax1.plot(
    xv, val_loss, linestyle='dotted', linewidth=3, color='tab:pink',
    label='Validation loss',
)
vacc, = ax2.plot(xv, val_acc, color='tab:green', label='Validation accuracy')

# Best epoch
yb = val_loss[int(best_epoch / epoch_freq)]
yc = val_acc[int(best_epoch / epoch_freq)]
ax1.plot(best_epoch + 1, yb, 'co', markersize=10)
#ax2.plot(best_epoch + 1, yc, 'co')
ax1.annotate('Best epoch: #{}\n Acc: {:.2%}'.format(best_epoch + 1, yc),
               (best_epoch + 1, yb),
               textcoords="offset points", # Where to position text
               xytext=(40, 100), # Distance from text to points (x,y)
               ha='center',
               )

# Axes labels
ax1.set_ylabel('BCE Loss', fontsize=14)
ax2.set_ylabel(
    'Validation acc. @ an {:.0%} threshold'.format(test_threshold), fontsize=14,
)
ax1.set_xlabel('Epoch', fontsize=14)
plt.xlim([1, num_epochs])
ax2.set_ylim(bottom=0., top=1.)
ax1.set_title('Training over {} epochs'.format(num_epochs), fontsize=17)

# Legend
fig.legend(
    [tloss, vloss, vacc],
    ['Training loss',
     'Validation loss',
     'Validation accuracy',
    ],
    loc='center',
    prop={'size': 14}
)

plt.tight_layout()
plt.show()
if save_ok:
    fig.savefig(os.path.join(fig_dir, 'stats.png'))

# %%
fig, ax = plt.subplots(nrows=3, figsize=(7, 8), sharex=True)

# Time axis
xt = np.linspace(1, num_epochs, len(train_loss))
xv = np.linspace(1, num_epochs, int((num_epochs - 1) / epoch_freq) + 1)

# Loss & accuracy plots
ax[0].plot(xt, train_loss, color='tab:blue', label='Training loss')
# ax[1].plot(xv, train_acc, color='tab:orange', label='Training accuracy')
ax[1].plot(
    xv, val_loss, linestyle='dotted', color='tab:pink', label='Validation loss'
)
ax[2].plot(xv, val_acc, color='tab:green', label='Validation accuracy')

# Best epoch
yb = val_loss[int(best_epoch / epoch_freq)]
yc = val_acc[int(best_epoch / epoch_freq)]
# ax[0].plot(best_epoch + 1, train_loss[int(best_epoch / epoch_freq)], 'yo')
# ax[1].plot(best_epoch + 1, train_acc[int(best_epoch / epoch_freq)], 'co')
ax[1].plot(best_epoch + 1, yb, 'co')
ax[2].plot(best_epoch + 1, yc, 'co')
ax[2].annotate('Epoch {}'.format(best_epoch + 1),
               (best_epoch + 1, yb),
               textcoords="offset points", # Where to position text
               xytext=(0, 50), # Distance from text to points (x,y)
               ha='center',
               )

# Axes labels
ax[0].set_ylabel('Training\nLoss')
# ax[1].set_ylabel('Training Acc\n@ {:.0%} threshold'.format(test_threshold))
ax[1].set_ylabel('Validation\nLoss')
ax[2].set_ylabel('ValidationAcc\n@ {:.0%} threshold'.format(test_threshold))
plt.xlabel('Epoch')
plt.xlim([1, num_epochs])
# ax[1].set_ylim(bottom=0., top=1.)
ax[2].set_ylim(bottom=0., top=1.)

# fig.legend()           
plt.tight_layout()
plt.show()
if save_ok:
    fig.savefig(os.path.join(fig_dir, 'split.png'))

# %% [markdown]
# ## Compute trained model performance

# %%
from models.classifier.utils import f1scores

model.load_state_dict(torch.load(best_weights))
f1, f1_thresholds = f1scores(model, val_loader)
# Out:
# Threshold 0.00 | F1 score 1.000
# Threshold 0.05 | F1 score 1.000
# Threshold 0.10 | F1 score 1.000
# Threshold 0.15 | F1 score 1.000
# Threshold 0.20 | F1 score 1.000
# Threshold 0.25 | F1 score 1.000
# Threshold 0.30 | F1 score 1.000
# Threshold 0.35 | F1 score 1.000
# Threshold 0.40 | F1 score 1.000
# Threshold 0.45 | F1 score 1.000
# Threshold 0.50 | F1 score 1.000
# Threshold 0.55 | F1 score 1.000
# Threshold 0.60 | F1 score 1.000
# Threshold 0.65 | F1 score 1.000
# Threshold 0.70 | F1 score 1.000
# Threshold 0.75 | F1 score 1.000
# Threshold 0.80 | F1 score 1.000
# Threshold 0.85 | F1 score 1.000
# Threshold 0.90 | F1 score 1.000
# Threshold 0.95 | F1 score 1.000
# Threshold 1.00 | F1 score 0.489

# %%
from models.classifier.utils import accuracy
acc = accuracy(model, val_loader, thresholds=f1_thresholds, num_classes=2)

# %%
fig, ax = plt.subplots(figsize=(7, 7))

acc_line, = ax.plot(
    f1_thresholds, acc, linewidth=3, linestyle='dotted', color='tab:blue'
)
f1_line, = ax.plot(
    f1_thresholds, f1, linewidth=1, linestyle='solid', color='tab:pink'
)

ax.set_xlabel('Threshold', fontsize=15)
ax.set_title(r'$F_1$ Score and Accuracy vs. Threshold', fontsize=17)

ax.set_xlim(left=0., right=1.)
ax.set_ylim(bottom=0., top=1.)

ax.legend(
    [f1_line, acc_line],
    [r'$F_1 = \frac{2\times(Precision \times Recall)}{Precision + Recall}$',
     'Accuracy'
    ],
    loc='lower center',
    prop={'size': 14}
)

ax.grid(True)
fig.tight_layout()
plt.show()

if save_ok:
    fig.savefig(os.path.join(fig_dir, 'f1-acc.png'))

# %%
fig, ax = plt.subplots(figsize=(7, 7))
f1_line = ax.plot(
    f1_thresholds, f1, linewidth=3, linestyle='solid', color='tab:pink'
)
ax.set_xlabel('Threshold', fontsize=15)
#ax.set_ylabel(
#    r'$F_1 = \frac{2\times(Precision \times Recall)}{Precision + Recall}$',
#    fontsize=18,
#)
ax.set_title(r'$F_1$ Score vs. Acceptance Threshold', fontsize=17)

ax.set_xlim(left=0., right=1.)
ax.set_ylim(bottom=0., top=1.)

ax.legend(
    f1_line,
    [r'$F_1 = \frac{2\times(Precision \times Recall)}{Precision + Recall}$',],
    loc='lower center',
    prop={'size': 18}
)

ax.grid(True)
fig.tight_layout()
plt.show()

if save_ok:
    fig.savefig(os.path.join(fig_dir, 'f1-scores.png'))
